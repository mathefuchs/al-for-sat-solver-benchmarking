# %% [markdown]
# # Prepare Data

# %% [markdown]
# ### Design Decisions

# %%
# Only include instances from SAT competition 202x
# instance_filter_expr = "local like %sat202%"
instance_filter_expr = ""

# %% [markdown]
# ### Load Data

# %%
import numpy as np
import pandas as pd

from gbd_tool.gbd_api import GBD
    
# Meta-data dataframe
with GBD(["gbd-data/meta.db"]) as gbd:
    features = gbd.get_features()
    features.remove("hash")
    meta_df = pd.DataFrame.from_records(
        gbd.query_search(instance_filter_expr, resolve=features),
        columns=gbd.get_features())

# Dataframe with all base features
with GBD([
    "gbd-data/meta.db",
    "gbd-data/base.db"
]) as gbd:
    features = gbd.get_features()
    for meta_feat in gbd.get_features(dbname="meta_db"):
        features.remove(meta_feat)
    features_with_hash = features.copy()
    features_with_hash.insert(0, "hash")
    base_features_df = pd.DataFrame.from_records(
        gbd.query_search(instance_filter_expr, resolve=features),
        columns=features_with_hash)
    
# Dataframe with all features
with GBD([
    "gbd-data/meta.db",
    "gbd-data/base.db",
    "gbd-data/gate.db",
]) as gbd:
    features = gbd.get_features()
    for meta_feat in gbd.get_features(dbname="meta_db"):
        features.remove(meta_feat)
    features_with_hash = features.copy()
    features_with_hash.insert(0, "hash")
    features_df = pd.DataFrame.from_records(
        gbd.query_search(instance_filter_expr, resolve=features),
        columns=features_with_hash)

# Dataframe with all base and satzilla features
with GBD([
    "gbd-data/meta.db",
    "gbd-data/base.db",
    "gbd-data/gate.db",
    "gbd-data/satzilla.db",
]) as gbd:
    features = gbd.get_features()
    for meta_feat in gbd.get_features(dbname="meta_db"):
        features.remove(meta_feat)
    features_with_hash = features.copy()
    features_with_hash.insert(0, "hash")
    features_satzilla_df = pd.DataFrame.from_records(
        gbd.query_search(instance_filter_expr, resolve=features),
        columns=features_with_hash)
    
# Dataframe with all runtimes
with GBD(["gbd-data/meta.db", "gbd-data/runtimes.db"]) as gbd:
    features = gbd.get_features()
    for meta_feat in gbd.get_features(dbname="meta_db"):
        features.remove(meta_feat)
    features_with_hash = features.copy()
    features_with_hash.insert(0, "hash")
    runtimes_df = pd.DataFrame.from_records(
        gbd.query_search(instance_filter_expr, resolve=features),
        columns=features_with_hash)
    
# Handle custom error codes
counts = {}
def convert_value(x: str) -> float:
    global counts
    if x is None or x == "empty" or x == "failed" or x == "memout" or x == "unverified":
        if x in counts:
            counts[x] += 1
        else:
            counts[x] = 1
        return np.nan
    elif x == "timeout":
        return np.inf
    else:
        try:
            return float(x)
        except ValueError as e:
            print(x)
            raise e

# Coerce into correct datatype and set index
for col_name in base_features_df.columns:
    if col_name == "hash":
        base_features_df[col_name] = base_features_df[col_name].astype("string")
    else:
        base_features_df[col_name] = base_features_df[col_name].map(convert_value)   
base_features_df.set_index("hash", inplace=True, drop=True)

for col_name in features_df.columns:
    if col_name == "hash":
        features_df[col_name] = features_df[col_name].astype("string")
    else:
        features_df[col_name] = features_df[col_name].map(convert_value)   
features_df.set_index("hash", inplace=True, drop=True)
   
for col_name in features_satzilla_df.columns:
    if col_name == "hash":
        features_satzilla_df[col_name] = features_satzilla_df[col_name].astype("string")
    else:
        features_satzilla_df[col_name] = features_satzilla_df[col_name].map(convert_value)   
features_satzilla_df.set_index("hash", inplace=True, drop=True)
    
for col_name in runtimes_df.columns:
    if col_name == "hash":
        runtimes_df[col_name] = runtimes_df[col_name].astype("string")
    else:
        runtimes_df[col_name] = runtimes_df[col_name].map(convert_value)  
runtimes_df.set_index("hash", inplace=True, drop=True)

# Only use instances with all feature values present
nan_feature_rows = np.any(np.isnan(features_df.replace([np.inf, -np.inf], np.nan)), axis=1)
base_features_df = base_features_df[~nan_feature_rows]
features_df = features_df[~nan_feature_rows]
features_satzilla_df = features_satzilla_df[~nan_feature_rows]
runtimes_df = runtimes_df[~nan_feature_rows]

# Drop march_nh and glucose_syrup solvers because of too many empty values (not timeout)
runtimes_df.drop(["march_nh", "glucose_syrup"], axis=1, inplace=True)

base_features_df.shape, features_df.shape, features_satzilla_df.shape, runtimes_df.shape
# Out:
# ((28225, 56), (28225, 113), (28225, 251), (28225, 16))

# %%
# Meta-data dataframe
with GBD(["gbd-data/meta.db"]) as gbd:
    features = gbd.get_features()
    features.remove("hash")
    meta_df = pd.DataFrame.from_records(
        gbd.query_search(instance_filter_expr, resolve=features),
        columns=gbd.get_features())

# Dataframe with all base features
with GBD([
    "gbd-data/meta.db",
    "gbd-data/base.db"
]) as gbd:
    features = gbd.get_features()
    for meta_feat in gbd.get_features(dbname="meta_db"):
        features.remove(meta_feat)
    features_with_hash = features.copy()
    features_with_hash.insert(0, "hash")
    base_features_df = pd.DataFrame.from_records(
        gbd.query_search(instance_filter_expr, resolve=features),
        columns=features_with_hash)
    
# Coerce into correct datatype and set index
for col_name in base_features_df.columns:
    if col_name == "hash":
        base_features_df[col_name] = base_features_df[col_name].astype("string")
    else:
        base_features_df[col_name] = base_features_df[col_name].map(convert_value)   
base_features_df.set_index("hash", inplace=True, drop=True)
meta_df.set_index("hash", inplace=True, drop=True)

# Only use instances with all feature values present
nan_feature_rows = np.any(np.isnan(base_features_df.replace([np.inf, -np.inf], np.nan)), axis=1)
base_features_df = base_features_df[~nan_feature_rows]
meta_df = meta_df.loc[base_features_df.index, :]
meta_df.shape, base_features_df.shape
# Out:
# ((29353, 9), (29353, 56))

# %%
counts
# Out:
# {None: 2778526, 'memout': 2, 'empty': 212128}

# %%
# Drop zero variance features
base_features_df.drop(base_features_df.columns[base_features_df.std() == 0], axis=1, inplace=True)
features_df.drop(features_df.columns[features_df.std() == 0], axis=1, inplace=True)
features_satzilla_df.drop(features_satzilla_df.columns[features_satzilla_df.std() == 0], axis=1, inplace=True)
runtimes_df.drop(runtimes_df.columns[runtimes_df.std() == 0], axis=1, inplace=True)

base_features_df.shape, features_df.shape, features_satzilla_df.shape, runtimes_df.shape
# Out:
# ((29353, 46), (28225, 97), (28225, 235), (28225, 16))

# %% [markdown]
# ### Compute statistics for each feature

# %%
pd.set_option("display.max_rows", 300)

# %%
features_df.replace([np.inf, -np.inf], np.nan).dropna().describe().transpose()
# Out:
#                           count          mean           std           min  \
# levels_and_variance      0.000000e+00  0.000000e+00  0.000000e+00
# levels_and_min           0.000000e+00  0.000000e+00  1.000000e+00
# levels_and_max           0.000000e+00  0.000000e+00  2.000000e+00
# levels_and_entropy       0.000000e+00  0.000000e+00  0.000000e+00
# levels_or_mean           0.000000e+00  0.000000e+00  1.000000e+00
# levels_or_variance       0.000000e+00  0.000000e+00  0.000000e+00
# levels_or_min            0.000000e+00  0.000000e+00  1.000000e+00
# levels_or_max            0.000000e+00  0.000000e+00  1.000000e+00
# levels_or_entropy        0.000000e+00  0.000000e+00  0.000000e+00
# levels_triv_mean         0.000000e+00  0.000000e+00  0.000000e+00
# levels_triv_variance     0.000000e+00  0.000000e+00  0.000000e+00
# levels_triv_min          0.000000e+00  0.000000e+00  0.000000e+00
# levels_triv_max          0.000000e+00  0.000000e+00  0.000000e+00
# levels_triv_entropy      0.000000e+00  0.000000e+00  0.000000e+00
# levels_equiv_mean        0.000000e+00  0.000000e+00  0.000000e+00
# levels_equiv_variance    0.000000e+00  0.000000e+00  0.000000e+00
# levels_equiv_min         0.000000e+00  0.000000e+00  0.000000e+00
# levels_equiv_max         0.000000e+00  0.000000e+00  0.000000e+00
# levels_equiv_entropy     0.000000e+00  0.000000e+00  0.000000e+00
# levels_full_mean         0.000000e+00  0.000000e+00  0.000000e+00
# levels_full_variance     0.000000e+00  0.000000e+00  0.000000e+00
# levels_full_min          0.000000e+00  0.000000e+00  0.000000e+00
# levels_full_max          0.000000e+00  0.000000e+00  0.000000e+00
# levels_full_entropy      0.000000e+00  0.000000e+00  0.000000e+00
# gate_features_runtime    0.000000e+00  1.000000e+00  7.000000e+00
#
#                                   max
# clauses                  8.730200e+08
# variables                2.886922e+07
# clause_size_1            8.876720e+05
# clause_size_2            8.785615e+08
# clause_size_3            9.399184e+07
# clause_size_4            1.469232e+07
# clause_size_5            1.572861e+07
# clause_size_6            7.674150e+06
# clause_size_7            6.896240e+05
# clause_size_8            3.279193e+09
# clause_size_9            3.178287e+06
# horn_clauses             1.614921e+08
# inv_horn_clauses         8.730144e+08
# positive_clauses         8.587380e+06
# negative_clauses         8.713977e+08
# horn_vars_mean           1.023244e+05
# horn_vars_variance       7.651367e+09
# horn_vars_max            2.252270e+05
# horn_vars_entropy        8.976864e+00
# inv_horn_vars_mean       3.010464e+04
# inv_horn_vars_variance   1.073943e+09
# inv_horn_vars_max        2.621440e+05
# inv_horn_vars_entropy    9.211690e+00
# balance_clause_mean      6.996871e+01
# balance_clause_variance  4.513781e+04
# balance_clause_min       6.000000e+00
# balance_clause_max       2.076060e+05
# balance_clause_entropy   3.916986e+00
# vcg_vdegrees_mean        9.938659e-01
# vcg_vdegrees_variance    3.409131e-01
# vcg_vdegrees_max         1.000000e+00
# vcg_vdegrees_entropy     3.071735e+00
# vcg_cdegrees_mean        9.999996e-01
# vcg_cdegrees_variance    9.260255e-01
# vcg_cdegrees_max         1.000000e+00
# vcg_cdegrees_entropy     3.253313e+00
# vg_degrees_mean          1.101055e+05
# vg_degrees_variance      7.154115e+09
# vg_degrees_max           5.242880e+05
# vg_degrees_entropy       9.211690e+00
# cg_degrees_mean          8.301289e+05
# cg_degrees_variance      1.326953e+11
# cg_degrees_min           1.064000e+03
# cg_degrees_max           1.350476e+08
# cg_degrees_entropy       1.148299e+01
# base_features_runtime    3.220000e+02
# n_vars                   2.886922e+07
# n_gates                  2.424489e+06
# n_roots                  8.876720e+05
# n_none                   2.886782e+07
# n_generic                1.188710e+05
# n_mono                   2.304063e+06
# n_and                    5.509590e+05
# n_or                     6.197780e+05
# n_triv                   4.505600e+04
# n_equiv                  1.308170e+05
# n_full                   1.293000e+03
# levels_mean              2.421506e+04
# levels_variance          3.585529e+08
# levels_max               5.996000e+04
# levels_entropy           1.405317e+01
# levels_generic_mean      1.025000e+03
# levels_generic_variance  8.109095e+04
# levels_generic_min       1.025000e+03
# levels_generic_max       1.376000e+03
# levels_generic_entropy   8.716159e+00
# levels_mono_mean         2.998060e+04
# levels_mono_variance     2.995639e+08
# levels_mono_min          1.000000e+00
# levels_mono_max          5.996000e+04
# levels_mono_entropy      1.588250e+01
# levels_and_mean          1.499650e+04
# levels_and_variance      1.948534e+08
# levels_and_min           5.150000e+02
# levels_and_max           5.188000e+04
# levels_and_entropy       1.470056e+01
# levels_or_mean           1.499130e+04
# levels_or_variance       2.221521e+08
# levels_or_min            5.140000e+02
# levels_or_max            5.188000e+04
# levels_or_entropy        1.479313e+01
# levels_triv_mean         2.169863e+01
# levels_triv_variance     1.816815e+02
# levels_triv_min          8.000000e+00
# levels_triv_max          5.500000e+01
# levels_triv_entropy      4.742931e+00
# levels_equiv_mean        2.394150e+04
# levels_equiv_variance    8.132914e+06
# levels_equiv_min         2.394100e+04
# levels_equiv_max         2.394200e+04
# levels_equiv_entropy     1.327137e+01
# levels_full_mean         4.753905e+01
# levels_full_variance     7.117381e+02
# levels_full_min          3.000000e+00
# levels_full_max          9.500000e+01
# levels_full_entropy      6.553419e+00
# gate_features_runtime    9.870000e+02

# %%
stats_per_column = []
for col_name in features_satzilla_df.columns:
    stats_per_column.append(features_satzilla_df[col_name].replace([np.inf, -np.inf], np.nan).dropna().describe())

pd.concat(stats_per_column, axis=1).transpose()
# Out:
#                                         count          mean           std  \
# clauses                                2526.0  8.999957e+06  4.770048e+07
# variables                              2526.0  4.676456e+05  1.405167e+06
# clause_size_1                          2526.0  3.497879e+04  1.238329e+05
# clause_size_2                          2526.0  1.296477e+07  4.728255e+07
# clause_size_3                          2526.0  1.159643e+06  4.582747e+06
# clause_size_4                          2526.0  3.166744e+05  1.596749e+06
# clause_size_5                          2526.0  3.503013e+04  3.698999e+05
# clause_size_6                          2526.0  6.111778e+06  5.909102e+04
# clause_size_7                          2526.0  1.731399e+04  5.839898e+04
# clause_size_8                          2526.0  3.132882e+09  5.236574e+08
# clause_size_9                          2526.0  3.643384e+04  6.735658e+04
# horn_clauses                           2526.0  1.988255e+06  7.854528e+06
# inv_horn_clauses                       2526.0  8.189686e+06  4.757654e+07
# DIAMETER_max                           1585.0  8.265237e+01  9.790567e+02
# DIAMETER_entropy                       1585.0 -1.055751e+00  3.151429e+01
# DIAMETER_featuretime                   1585.0  1.385491e+01  3.334057e+01
# cl_num_mean                            1581.0  7.116122e+02  1.093030e+03
# cl_num_coeff_variation                 1581.0  1.857350e-01  2.902771e-01
# cl_num_min                             1581.0  5.150006e+02  9.740697e+02
# cl_num_max                             1581.0  1.000201e+03  1.345203e+03
# cl_num_q90                             1581.0  9.419810e+02  1.319587e+03
# cl_num_q10                             1581.0  5.270835e+02  9.753510e+02
# cl_num_q75                             1581.0  8.484175e+02  1.255397e+03
# cl_num_q25                             1581.0  5.888134e+02  1.017281e+03
# cl_num_q50                             1581.0  7.156034e+02  1.126621e+03
# cl_size_mean                           1581.0  2.455452e+01  9.160429e+01
# cl_size_coeff_variation                1581.0  1.316054e-01  2.684488e-01
# cl_size_min                            1581.0  1.446061e+01  2.892911e+01
# cl_size_max                            1581.0  4.629955e+01  2.798064e+02
# cl_size_q90                            1581.0  4.115123e+01  2.777834e+02
# cl_size_q10                            1581.0  1.324200e+01  4.371462e+01
# cl_size_q75                            1581.0  2.945383e+01  1.778028e+02
# cl_size_q25                            1581.0  1.464881e+01  4.448735e+01
# cl_size_q50                            1581.0  2.053520e+01  8.779261e+01
# cl_featuretime                         1581.0  1.416825e-03  3.161306e+01
# SP_bias_mean                           1583.0  4.819123e-01  2.785250e-01
# SP_bias_coeff_variation                1583.0  6.509535e-01  5.265385e-01
# SP_bias_min                            1583.0  1.884375e-02  1.018795e-01
# SP_bias_max                            1583.0  9.157649e-01  1.639325e-01
# SP_bias_q90                            1583.0 -1.211180e+00  3.151762e+01
# SP_bias_q10                            1583.0 -1.706235e+00  3.148754e+01
# SP_bias_q75                            1583.0 -1.306863e+00  3.151209e+01
# SP_bias_q25                            1583.0 -1.601450e+00  3.149417e+01
# SP_bias_q50                            1583.0 -1.455654e+00  3.150318e+01
# SP_unconstraint_mean                   1583.0  1.092081e-01  1.021933e-01
# SP_unconstraint_coeff_variation        1583.0  1.150650e+00  1.805572e+00
# SP_unconstraint_min                    1583.0  8.008344e-03  4.267393e-02
# SP_unconstraint_max                    1583.0  3.870690e-01  2.270115e-01
# SP_unconstraint_q90                    1583.0 -1.730963e+00  3.148492e+01
# SP_unconstraint_q10                    1583.0 -1.909124e+00  3.147355e+01
# SP_unconstraint_q75                    1583.0 -1.772671e+00  3.148230e+01
# SP_unconstraint_q25                    1583.0 -1.889573e+00  3.147479e+01
# SP_unconstraint_q50                    1583.0 -1.852241e+00  3.147716e+01
# sp_featuretime                         1583.0  2.477031e+01  1.256084e+02
# vars_reduced_depth_1                   1579.0 -1.943507e+00  3.151136e+01
# vars_reduced_depth_4                   1579.0 -1.936760e+00  3.151182e+01
# vars_reduced_depth_16                  1579.0 -1.892634e+00  3.151505e+01
# vars_reduced_depth_64                  1579.0 -1.841940e+00  3.151850e+01
# vars_reduced_depth_256                 1579.0 -1.783791e+00  3.152249e+01
# clause_size_6                          6.101292e+06  6.101292e+06
# clause_size_7                          0.000000e+00  0.000000e+00
# clause_size_8                          1.241745e+07  3.276047e+09
# clause_size_9                          0.000000e+00  3.257100e+04
# horn_clauses                           1.700000e+01  2.495925e+04
# inv_horn_clauses                       4.300000e+01  4.786100e+04
# positive_clauses                       1.000000e+00  3.812500e+02
# negative_clauses                       1.000000e+00  4.058000e+03
# horn_vars_mean                         1.657170e-01  4.009789e+00
# horn_vars_variance                     3.853891e-06  1.099232e+01
# horn_vars_max                          1.000000e+00  2.800000e+01
# horn_vars_entropy                      7.490312e-05  1.697868e+00
# inv_horn_vars_mean                     7.639478e-01  5.113703e+00
# inv_horn_vars_variance                 1.169638e-01  3.208366e+01
# inv_horn_vars_max                      4.000000e+00  5.000000e+01
# inv_horn_vars_entropy                  5.345894e-03  1.990598e+00
# balance_clause_mean                    2.000117e+00  2.350500e+00
# balance_clause_variance                0.000000e+00  2.495947e-01
# balance_clause_min                     1.000000e+00  1.000000e+00
# balance_clause_max                     3.000000e+00  4.000000e+00
# balance_clause_entropy                 0.000000e+00  8.009823e-01
# vcg_vdegrees_mean                      0.000000e+00  3.355601e-01
# vcg_vdegrees_variance                  0.000000e+00  1.801859e-01
# vcg_vdegrees_max                       0.000000e+00  1.000000e+00
# vcg_vdegrees_entropy                   0.000000e+00  1.029939e+00
# vcg_cdegrees_mean                      1.784454e-05  4.750384e-01
# vcg_cdegrees_variance                  3.184274e-10  1.403738e-01
# vcg_cdegrees_max                       4.705440e-05  1.000000e+00
# vcg_cdegrees_entropy                   0.000000e+00  8.133492e-01
# vg_degrees_mean                        1.351992e+00  8.013889e+00
# vg_degrees_variance                    9.875780e-02  9.842613e+01
# vg_degrees_max                         8.000000e+00  9.100000e+01
# vg_degrees_entropy                     3.979570e-04  1.803244e+00
# cg_degrees_mean                        3.235142e+00  1.790584e+01
# cg_degrees_variance                    0.000000e+00  7.593144e+02
# cg_degrees_min                         0.000000e+00  0.000000e+00
# cg_degrees_max                         1.100000e+01  3.210000e+02
# cg_degrees_entropy                     0.000000e+00  2.941692e+00
# base_features_runtime                  0.000000e+00  0.000000e+00
# n_vars                                 3.200000e+01  1.197600e+04
# n_gates                                0.000000e+00  0.000000e+00
# n_roots                                1.000000e+00  8.000000e+00
# n_none                                 2.200000e+01  6.322000e+03
# n_generic                              0.000000e+00  0.000000e+00
# n_mono                                 0.000000e+00  0.000000e+00
# n_and                                  0.000000e+00  0.000000e+00
# n_or                                   0.000000e+00  0.000000e+00
# n_triv                                 0.000000e+00  0.000000e+00
# n_equiv                                0.000000e+00  0.000000e+00
# n_full                                 0.000000e+00  0.000000e+00
# levels_mean                            0.000000e+00  0.000000e+00
# levels_variance                        0.000000e+00  0.000000e+00
# levels_max                             0.000000e+00  0.000000e+00
# levels_entropy                         0.000000e+00  0.000000e+00
# levels_generic_mean                    0.000000e+00  0.000000e+00
# levels_generic_variance                0.000000e+00  0.000000e+00
# levels_generic_min                     0.000000e+00  0.000000e+00
# levels_generic_max                     0.000000e+00  0.000000e+00
# levels_generic_entropy                 0.000000e+00  0.000000e+00
# levels_mono_mean                       0.000000e+00  0.000000e+00
# levels_mono_variance                   0.000000e+00  0.000000e+00
# levels_mono_min                        0.000000e+00  0.000000e+00
# levels_mono_max                        0.000000e+00  0.000000e+00
# levels_mono_entropy                    0.000000e+00  0.000000e+00
# levels_and_mean                        0.000000e+00  0.000000e+00
# levels_and_variance                    0.000000e+00  0.000000e+00
# levels_and_min                         0.000000e+00  0.000000e+00
# levels_and_max                         0.000000e+00  0.000000e+00
# levels_and_entropy                     0.000000e+00  0.000000e+00
# levels_or_mean                         0.000000e+00  0.000000e+00
# levels_or_variance                     0.000000e+00  0.000000e+00
# levels_or_min                          0.000000e+00  0.000000e+00
# levels_or_max                          0.000000e+00  0.000000e+00
# levels_or_entropy                      0.000000e+00  0.000000e+00
# levels_triv_mean                       0.000000e+00  0.000000e+00
# levels_triv_variance                   0.000000e+00  0.000000e+00
# levels_triv_min                        0.000000e+00  0.000000e+00
# levels_triv_max                        0.000000e+00  0.000000e+00
# levels_triv_entropy                    0.000000e+00  0.000000e+00
# levels_equiv_mean                      0.000000e+00  0.000000e+00
# levels_equiv_variance                  0.000000e+00  0.000000e+00
# levels_equiv_min                       0.000000e+00  0.000000e+00
# levels_equiv_max                       0.000000e+00  0.000000e+00
# levels_equiv_entropy                   0.000000e+00  0.000000e+00
# levels_full_mean                       0.000000e+00  0.000000e+00
# levels_full_variance                   0.000000e+00  0.000000e+00
# levels_full_min                        0.000000e+00  0.000000e+00
# levels_full_max                        0.000000e+00  0.000000e+00
# levels_full_entropy                    0.000000e+00  0.000000e+00
# gate_features_runtime                  0.000000e+00  0.000000e+00
# nvarsOrig                              5.000000e+01  1.128975e+04
# nclausesOrig                           5.500000e+01  8.770000e+04
# nvars                                  0.000000e+00  3.943500e+03
# nclauses                               0.000000e+00  3.960100e+04
# reducedVars                           -5.120000e+02  2.248672e-01
# reducedClauses                        -5.120000e+02  4.716212e-02
# Pre_featuretime                        0.000000e+00  2.800000e-01
# vars_clauses_ratio                    -5.120000e+02  6.357777e-02
# POSNEG_RATIO_CLAUSE_mean               0.000000e+00  3.647697e-01
# POSNEG_RATIO_CLAUSE_coeff_variation    0.000000e+00  5.646724e-01
# POSNEG_RATIO_CLAUSE_min                0.000000e+00  0.000000e+00
# POSNEG_RATIO_CLAUSE_max                0.000000e+00  1.000000e+00
# POSNEG_RATIO_CLAUSE_entropy           -5.120000e+02  7.766813e-01
# VCG_CLAUSE_mean                        0.000000e+00  2.333200e-05
# VCG_CLAUSE_coeff_variation             0.000000e+00  2.578670e-01
# VCG_CLAUSE_min                         0.000000e+00  1.383550e-05
# VCG_CLAUSE_max                         0.000000e+00  4.629015e-04
# VCG_CLAUSE_entropy                    -5.120000e+02  4.880034e-01
# UNARY                                 -5.120000e+02  0.000000e+00
# BINARYplus                            -5.120000e+02  1.040242e-01
# TRINARYplus                           -5.120000e+02  5.632845e-01
# Basic_featuretime                     -5.120000e+02 -0.000000e+00
# VCG_VAR_mean                           0.000000e+00  2.333200e-05
# VCG_VAR_coeff_variation                0.000000e+00  4.763109e-01
# VCG_VAR_min                            0.000000e+00  2.661500e-06
# VCG_VAR_max                            0.000000e+00  3.819282e-04
# VCG_VAR_entropy                       -5.120000e+02  1.721137e+00
# POSNEG_RATIO_VAR_mean                  0.000000e+00  7.373105e-02
# POSNEG_RATIO_VAR_stdev                 0.000000e+00  7.570729e-02
# POSNEG_RATIO_VAR_min                   0.000000e+00  0.000000e+00
# POSNEG_RATIO_VAR_max                   0.000000e+00  6.363636e-01
# POSNEG_RATIO_VAR_entropy              -5.120000e+02  1.359985e+00
# HORNY_VAR_mean                         0.000000e+00  9.821000e-06
# HORNY_VAR_coeff_variation              0.000000e+00  6.935188e-01
# HORNY_VAR_min                          0.000000e+00  5.050000e-07
# HORNY_VAR_max                          0.000000e+00  1.756890e-04
# HORNY_VAR_entropy                     -5.120000e+02  1.421677e+00
# horn_clauses_fraction                 -5.120000e+02  4.101667e-01
# VG_mean                                0.000000e+00  4.155050e-05
# VG_coeff_variation                     0.000000e+00  6.289663e-01
# VG_min                                 0.000000e+00  1.886000e-06
# VG_max                                 0.000000e+00  3.386455e-04
# KLB_featuretime                       -5.120000e+02  6.000000e-02
# CG_mean                               -1.000000e+00 -1.000000e+00
# CG_coeff_variation                    -0.000000e+00 -0.000000e+00
# CG_min                                -1.000000e+00 -1.000000e+00
# CG_max                                 0.000000e+00  0.000000e+00
# CG_entropy                            -5.120000e+02 -5.120000e+02
# cluster_coeff_mean                    -1.000000e+00 -1.000000e+00
# cluster_coeff_coeff_variation         -0.000000e+00 -0.000000e+00
# cluster_coeff_min                     -1.000000e+00 -1.000000e+00
# cluster_coeff_max                      0.000000e+00  0.000000e+00
# cluster_coeff_entropy                 -5.120000e+02 -0.000000e+00
# CG_featuretime                        -5.120000e+02  1.759000e+01
# DIAMETER_mean                          0.000000e+00  5.720980e+00
# DIAMETER_coeff_variation               0.000000e+00  6.093519e-03
# DIAMETER_min                           0.000000e+00  5.000000e+00
# DIAMETER_max                           0.000000e+00  6.000000e+00
# DIAMETER_entropy                      -5.120000e+02  3.388856e-01
# DIAMETER_featuretime                  -5.120000e+02  1.278000e+01
# cl_num_mean                            0.000000e+00  0.000000e+00
# cl_num_coeff_variation                 0.000000e+00  0.000000e+00
# cl_num_min                             0.000000e+00  0.000000e+00
# cl_num_max                             0.000000e+00  0.000000e+00
# cl_num_q90                            -5.120000e+02  0.000000e+00
# cl_num_q10                            -5.120000e+02  0.000000e+00
# cl_num_q75                            -5.120000e+02  0.000000e+00
# cl_num_q25                            -5.120000e+02  0.000000e+00
# cl_num_q50                            -5.120000e+02  0.000000e+00
# cl_size_mean                           0.000000e+00  0.000000e+00
# cl_size_coeff_variation                0.000000e+00  0.000000e+00
# cl_size_min                            0.000000e+00  0.000000e+00
# cl_size_max                            0.000000e+00  0.000000e+00
# cl_size_q90                           -5.120000e+02  0.000000e+00
# cl_size_q10                           -5.120000e+02  0.000000e+00
# cl_size_q75                           -5.120000e+02  0.000000e+00
# cl_size_q25                           -5.120000e+02  0.000000e+00
# cl_size_q50                           -5.120000e+02  0.000000e+00
# cl_featuretime                        -5.120000e+02  2.000000e+00
# SP_bias_mean                           0.000000e+00  2.291313e-01
# SP_bias_coeff_variation                0.000000e+00  3.183676e-01
# SP_bias_min                            0.000000e+00  0.000000e+00
# SP_bias_max                            0.000000e+00  9.068974e-01
# SP_bias_q90                           -5.120000e+02  5.157257e-01
# SP_bias_q10                           -5.120000e+02  1.924910e-02
# SP_bias_q75                           -5.120000e+02  3.957139e-01
# SP_bias_q25                           -5.120000e+02  9.094786e-02
# SP_bias_q50                           -5.120000e+02  1.994896e-01
# SP_unconstraint_mean                   0.000000e+00  3.536216e-02
# SP_unconstraint_coeff_variation        0.000000e+00  5.920914e-01
# SP_unconstraint_min                   -0.000000e+00  0.000000e+00
# SP_unconstraint_max                    0.000000e+00  2.397164e-01
# SP_unconstraint_q90                   -5.120000e+02  5.552675e-02
# SP_unconstraint_q10                   -5.120000e+02  2.131800e-05
# SP_unconstraint_q75                   -5.120000e+02  4.454071e-02
# SP_unconstraint_q25                   -5.120000e+02  1.991429e-03
# SP_unconstraint_q50                   -5.120000e+02  1.821948e-02
# sp_featuretime                        -5.120000e+02  1.120000e+00
# vars_reduced_depth_1                  -5.120000e+02  0.000000e+00
# vars_reduced_depth_4                  -5.120000e+02  0.000000e+00
# vars_reduced_depth_16                 -5.120000e+02  9.288000e-06
# vars_reduced_depth_64                 -5.120000e+02  6.752405e-04
# vars_reduced_depth_256                -5.120000e+02  1.541459e-03
# unit_featuretime                      -5.120000e+02  6.000000e-02
# LP_OBJ                                -5.120000e+02 -6.012839e-02
# LPSLack_mean                           0.000000e+00  5.225761e-02
# LPSLack_coeff_variation                0.000000e+00  7.466947e-01
# LPSLack_min                           -0.000000e+00  0.000000e+00
# LPSLack_max                            0.000000e+00  4.932977e-01
# lpIntRatio                            -5.120000e+02  2.177310e-01
# lpTIME                                 0.000000e+00  2.570000e+00
# saps_BestSolution_Mean                -5.120000e+02  2.133465e+02
# saps_BestSolution_CoeffVariance       -5.120000e+02  0.000000e+00
# saps_FirstLocalMinStep_Mean           -5.120000e+02  0.000000e+00
# saps_FirstLocalMinStep_CoeffVariance  -5.120000e+02  0.000000e+00
# saps_FirstLocalMinStep_Median         -5.120000e+02  0.000000e+00
# saps_BestAvgImprovement_Mean          -5.120000e+02  9.998445e-01
# saps_BestAvgImprovement_CoeffVariance -5.120000e+02  0.000000e+00
# saps_FirstLocalMinRatio_Mean          -5.120000e+02  8.828250e-01
# saps_FirstLocalMinRatio_CoeffVariance -5.120000e+02  0.000000e+00
# ls_saps_featuretime                   -5.120000e+02  2.220000e+00
# gsat_BestSolution_Mean                -5.120000e+02  2.077220e+02
# gsat_BestSolution_CoeffVariance       -5.120000e+02  0.000000e+00
# gsat_FirstLocalMinStep_Mean           -5.120000e+02  0.000000e+00
# gsat_FirstLocalMinStep_CoeffVariance  -5.120000e+02  0.000000e+00
# gsat_FirstLocalMinStep_Median         -5.120000e+02  0.000000e+00
# gsat_BestAvgImprovement_Mean          -5.120000e+02  4.178900e-01
# gsat_BestAvgImprovement_CoeffVariance -5.120000e+02  0.000000e+00
# gsat_FirstLocalMinRatio_Mean          -5.120000e+02  8.757770e-01
# gsat_FirstLocalMinRatio_CoeffVariance -5.120000e+02  0.000000e+00
# ls_gsat_featuretime                   -5.120000e+02  2.460000e+00
# lobjois_mean_depth_over_vars          -5.120000e+02  5.963037e-02
# lobjois_log_num_nodes_over_vars       -5.120000e+02  1.600893e-01
# lobjois_featuretime                   -5.120000e+02  2.000000e+00
# saps_FirstLocalMinStep_Q_10           -5.120000e+02  0.000000e+00
# saps_FirstLocalMinStep_Q_90           -5.120000e+02  0.000000e+00
# gsat_FirstLocalMinStep_Q_10           -5.120000e+02  0.000000e+00
# gsat_FirstLocalMinStep_Q_90           -5.120000e+02  0.000000e+00
#
#                                                 50%           75%  \
# clauses                                4.789850e+05  3.051494e+06
# variables                              4.335450e+04  3.197802e+05
# clause_size_1                          1.480000e+02  1.938000e+03
# clause_size_2                          5.650376e+06  6.724738e+06
# clause_size_3                          5.979750e+04  6.084300e+05
# clause_size_4                          2.745000e+02  3.120800e+04
# clause_size_5                          0.000000e+00  2.630000e+03
# clause_size_6                          6.101292e+06  6.104896e+06
# clause_size_7                          0.000000e+00  1.300000e+02
# clause_size_8                          3.276047e+09  3.276047e+09
# clause_size_9                          3.257100e+04  3.257200e+04
# horn_clauses                           1.358945e+05  8.687402e+05
# inv_horn_clauses                       2.115340e+05  1.861038e+06
# positive_clauses                       1.984500e+03  3.869525e+04
# negative_clauses                       3.102400e+04  4.630238e+05
# horn_vars_mean                         6.842702e+00  1.494875e+01
# horn_vars_variance                     7.881551e+01  3.944115e+02
# horn_vars_max                          1.065000e+02  4.720000e+02
# horn_vars_entropy                      2.389622e+00  3.255368e+00
# inv_horn_vars_mean                     8.600518e+00  2.227584e+01
# inv_horn_vars_variance                 1.419222e+02  2.292772e+03
# inv_horn_vars_max                      1.595000e+02  7.510000e+02
# inv_horn_vars_entropy                  2.427046e+00  3.578723e+00
# balance_clause_mean                    2.676114e+00  3.339784e+00
# balance_clause_variance                7.057130e-01  3.293877e+00
# balance_clause_min                     1.000000e+00  1.000000e+00
# balance_clause_max                     8.000000e+00  5.500000e+01
# balance_clause_entropy                 1.008248e+00  1.406798e+00
# vcg_vdegrees_mean                      4.809324e-01  5.429097e-01
# vcg_vdegrees_variance                  2.263505e-01  2.541094e-01
# vcg_vdegrees_max                       1.000000e+00  1.000000e+00
# vcg_vdegrees_entropy                   1.430182e+00  1.631476e+00
# vcg_cdegrees_mean                      7.475507e-01  8.706087e-01
# vcg_cdegrees_variance                  3.415312e-01  4.784094e-01
# vcg_cdegrees_max                       1.000000e+00  1.000000e+00
# vcg_cdegrees_entropy                   1.420888e+00  1.814314e+00
# vg_degrees_mean                        1.480666e+01  7.873814e+01
# vg_degrees_variance                    4.894890e+02  1.296945e+04
# vg_degrees_max                         4.010000e+02  1.398000e+03
# vg_degrees_entropy                     2.620323e+00  3.916938e+00
# cg_degrees_mean                        5.007985e+01  3.120182e+02
# cg_degrees_variance                    6.982287e+03  1.152944e+05
# cg_degrees_min                         0.000000e+00  2.000000e+00
# cg_degrees_max                         1.467000e+03  8.222250e+03
# cg_degrees_entropy                     4.628764e+00  6.512889e+00
# base_features_runtime                  0.000000e+00  2.000000e+00
# n_vars                                 4.335450e+04  3.197802e+05
# n_gates                                2.700000e+01  3.948750e+03
# n_roots                                1.950000e+02  2.316000e+03
# n_none                                 2.947150e+04  1.957260e+05
# n_generic                              0.000000e+00  0.000000e+00
# n_mono                                 1.750000e+01  1.092000e+03
# n_and                                  0.000000e+00  2.000000e+00
# n_or                                   0.000000e+00  5.750000e+00
# n_triv                                 0.000000e+00  0.000000e+00
# n_equiv                                0.000000e+00  0.000000e+00
# n_full                                 0.000000e+00  0.000000e+00
# levels_mean                            8.673082e-04  1.201732e+00
# levels_variance                        9.862052e-04  2.011838e+00
# levels_max                             1.000000e+00  1.300000e+01
# levels_entropy                         9.206456e-03  7.830163e-01
# levels_generic_mean                    0.000000e+00  0.000000e+00
# levels_generic_variance                0.000000e+00  0.000000e+00
# levels_generic_min                     0.000000e+00  0.000000e+00
# levels_generic_max                     0.000000e+00  0.000000e+00
# levels_generic_entropy                 0.000000e+00  0.000000e+00
# levels_mono_mean                       1.000000e+00  2.121739e+00
# levels_mono_variance                   0.000000e+00  4.190033e-01
# levels_mono_min                        1.000000e+00  1.000000e+00
# levels_mono_max                        1.000000e+00  3.000000e+00
# levels_mono_entropy                    0.000000e+00  1.000000e+00
# levels_and_mean                        0.000000e+00  1.996847e+00
# levels_and_variance                    0.000000e+00  0.000000e+00
# levels_and_min                         0.000000e+00  1.000000e+00
# levels_and_max                         0.000000e+00  2.000000e+00
# levels_and_entropy                     0.000000e+00  0.000000e+00
# levels_or_mean                         0.000000e+00  1.000000e+00
# levels_or_variance                     0.000000e+00  0.000000e+00
# levels_or_min                          0.000000e+00  1.000000e+00
# levels_or_max                          0.000000e+00  1.000000e+00
# levels_or_entropy                      0.000000e+00  0.000000e+00
# levels_triv_mean                       0.000000e+00  0.000000e+00
# levels_triv_variance                   0.000000e+00  0.000000e+00
# levels_triv_min                        0.000000e+00  0.000000e+00
# levels_triv_max                        0.000000e+00  0.000000e+00
# levels_triv_entropy                    0.000000e+00  0.000000e+00
# levels_equiv_mean                      0.000000e+00  0.000000e+00
# levels_equiv_variance                  0.000000e+00  0.000000e+00
# levels_equiv_min                       0.000000e+00  0.000000e+00
# levels_equiv_max                       0.000000e+00  0.000000e+00
# levels_equiv_entropy                   0.000000e+00  0.000000e+00
# levels_full_mean                       0.000000e+00  0.000000e+00
# levels_full_variance                   0.000000e+00  0.000000e+00
# levels_full_min                        0.000000e+00  0.000000e+00
# levels_full_max                        0.000000e+00  0.000000e+00
# levels_full_entropy                    0.000000e+00  0.000000e+00
# gate_features_runtime                  1.000000e+00  7.000000e+00
# nvarsOrig                              5.610800e+04  3.140482e+05
# nclausesOrig                           4.246990e+05  3.032070e+06
# nvars                                  2.946950e+04  1.420075e+05
# nclauses                               2.700310e+05  2.220420e+06
# reducedVars                            6.893254e-01  1.504732e+00
# reducedClauses                         2.233760e-01  5.582932e-01
# Pre_featuretime                        2.550000e+00  1.527500e+01
# vars_clauses_ratio                     1.537318e-01  1.865951e-01
# POSNEG_RATIO_CLAUSE_mean               4.387148e-01  6.078184e-01
# POSNEG_RATIO_CLAUSE_coeff_variation    7.071104e-01  8.286112e-01
# POSNEG_RATIO_CLAUSE_min                0.000000e+00  0.000000e+00
# POSNEG_RATIO_CLAUSE_max                1.000000e+00  1.000000e+00
# POSNEG_RATIO_CLAUSE_entropy            1.082733e+00  1.448981e+00
# VCG_CLAUSE_mean                        1.087940e-04  8.222058e-04
# VCG_CLAUSE_coeff_variation             4.946400e-01  1.674319e+00
# VCG_CLAUSE_min                         6.760750e-05  5.031135e-04
# VCG_CLAUSE_max                         1.565010e-03  5.888643e-03
# VCG_CLAUSE_entropy                     9.112166e-01  1.218764e+00
# UNARY                                  0.000000e+00  0.000000e+00
# BINARYplus                             2.412826e-01  7.950542e-01
# TRINARYplus                            7.956096e-01  9.750529e-01
# Basic_featuretime                      6.000000e-02  3.850000e-01
# VCG_VAR_mean                           1.087940e-04  8.222058e-04
# VCG_VAR_coeff_variation                1.031289e+00  1.990681e+00
# VCG_VAR_min                            2.665800e-05  2.289147e-04
# VCG_VAR_max                            2.231027e-03  9.189853e-03
# VCG_VAR_entropy                        2.332700e+00  2.922147e+00
# POSNEG_RATIO_VAR_mean                  1.977439e-01  3.342739e-01
# POSNEG_RATIO_VAR_stdev                 1.369098e-01  2.387128e-01
# POSNEG_RATIO_VAR_min                   0.000000e+00  0.000000e+00
# POSNEG_RATIO_VAR_max                   8.088235e-01  9.736594e-01
# POSNEG_RATIO_VAR_entropy               1.959395e+00  2.629119e+00
# HORNY_VAR_mean                         5.130900e-05  3.287870e-04
# HORNY_VAR_coeff_variation              1.147995e+00  2.149027e+00
# HORNY_VAR_min                          5.560000e-06  4.911600e-05
# HORNY_VAR_max                          8.923110e-04  3.545294e-03
# HORNY_VAR_entropy                      1.983954e+00  2.604083e+00
# horn_clauses_fraction                  5.293142e-01  8.320400e-01
# VG_mean                                1.266990e-04  7.768605e-04
# VG_coeff_variation                     1.035712e+00  1.566436e+00
# VG_min                                 2.136800e-05  1.896775e-04
# VG_max                                 1.994957e-03  6.338902e-03
# KLB_featuretime                        2.720000e+00  5.969000e+01
# CG_mean                               -1.000000e+00  6.044950e-05
# CG_coeff_variation                     0.000000e+00  4.789540e-02
# CG_min                                -1.000000e+00  1.298400e-05
# CG_max                                 0.000000e+00  6.569995e-04
# CG_entropy                            -5.120000e+02  1.063497e+00
# cluster_coeff_mean                    -1.000000e+00  6.185471e-02
# cluster_coeff_coeff_variation          0.000000e+00  4.385329e-02
# cluster_coeff_min                     -1.000000e+00  1.234415e-03
# cluster_coeff_max                      0.000000e+00  1.250000e-01
# cluster_coeff_entropy                  0.000000e+00  7.453134e-01
# CG_featuretime                         2.006000e+01  2.030000e+01
# DIAMETER_mean                          8.718750e+00  2.437179e+01
# DIAMETER_coeff_variation               6.317140e-02  9.359776e-02
# DIAMETER_min                           7.000000e+00  1.900000e+01
# DIAMETER_max                           1.000000e+01  2.700000e+01
# DIAMETER_entropy                       8.186893e-01  1.323784e+00
# DIAMETER_featuretime                   2.002000e+01  2.020000e+01
# cl_num_mean                            1.140000e+02  1.014143e+03
# cl_num_coeff_variation                 0.000000e+00  3.010781e-01
# cl_num_min                             1.700000e+01  6.080000e+02
# cl_num_max                             2.290000e+02  1.653000e+03
# cl_num_q90                             1.890000e+02  1.479000e+03
# cl_num_q10                             2.200000e+01  6.550000e+02
# cl_num_q75                             1.350000e+02  1.218000e+03
# cl_num_q25                             3.700000e+01  7.610000e+02
# cl_num_q50                             8.800000e+01  9.890000e+02
# cl_size_mean                           9.729926e+00  2.832161e+01
# cl_size_coeff_variation                0.000000e+00  1.771724e-01
# cl_size_min                            4.957219e+00  2.125839e+01
# cl_size_max                            1.551945e+01  3.747562e+01
# cl_size_q90                            1.237959e+01  3.541948e+01
# cl_size_q10                            5.861111e+00  2.237592e+01
# cl_size_q75                            9.632184e+00  3.156667e+01
# cl_size_q25                            6.413580e+00  2.520510e+01
# cl_size_q50                            8.437870e+00  2.789258e+01
# cl_featuretime                         2.000000e+00  2.020000e+00
# SP_bias_mean                           4.494451e-01  7.219679e-01
# SP_bias_coeff_variation                5.810830e-01  7.515832e-01
# SP_bias_min                            0.000000e+00  1.950800e-05
# SP_bias_max                            9.983604e-01  1.000000e+00
# SP_bias_q90                            8.266475e-01  9.806941e-01
# SP_bias_q10                            6.335000e-02  2.694472e-01
# SP_bias_q75                            6.587052e-01  9.337421e-01
# SP_bias_q25                            1.986217e-01  6.113717e-01
# SP_bias_q50                            4.334038e-01  8.330253e-01
# SP_unconstraint_mean                   7.606172e-02  1.327444e-01
# SP_unconstraint_coeff_variation        8.184184e-01  1.223912e+00
# SP_unconstraint_min                    0.000000e+00  0.000000e+00
# SP_unconstraint_max                    3.491345e-01  5.000000e-01
# SP_unconstraint_q90                    1.544869e-01  3.570462e-01
# SP_unconstraint_q10                    5.462707e-03  2.100362e-02
# SP_unconstraint_q75                    1.016149e-01  2.411908e-01
# SP_unconstraint_q25                    1.845818e-02  4.583084e-02
# SP_unconstraint_q50                    4.215244e-02  1.188272e-01
# sp_featuretime                         3.580000e+00  2.262000e+01
# vars_reduced_depth_1                   0.000000e+00  5.696200e-04
# vars_reduced_depth_4                   2.181550e-04  1.571544e-03
# vars_reduced_depth_16                  8.726000e-04  1.052022e-02
# vars_reduced_depth_64                  6.323134e-03  6.088070e-02
# vars_reduced_depth_256                 1.251033e-02  1.766124e-01
# unit_featuretime                       5.200000e-01  3.500000e+00
# LP_OBJ                                 1.536678e-02  4.148060e-02
# LPSLack_mean                           1.265425e-01  2.199832e-01
# LPSLack_coeff_variation                1.191490e+00  2.006284e+00
# LPSLack_min                            0.000000e+00  0.000000e+00
# LPSLack_max                            5.000000e-01  5.000000e-01
# lpIntRatio                             5.627513e-01  7.596949e-01
# lpTIME                                 2.029000e+01  3.038400e+02
# saps_BestSolution_Mean                 6.743000e+03  4.174850e+05
# saps_BestSolution_CoeffVariance        0.000000e+00  4.728210e-01
# saps_FirstLocalMinStep_Mean            6.370150e+01  1.291140e+03
# saps_FirstLocalMinStep_CoeffVariance   0.000000e+00  8.827010e-02
# saps_FirstLocalMinStep_Median          6.400000e+01  1.292500e+03
# saps_BestAvgImprovement_Mean           5.703410e+00  2.553985e+01
# saps_BestAvgImprovement_CoeffVariance  0.000000e+00  2.833655e-01
# saps_FirstLocalMinRatio_Mean           1.151710e+00  6.678475e+00
# saps_FirstLocalMinRatio_CoeffVariance  0.000000e+00  5.282270e-02
# ls_saps_featuretime                    2.480000e+00  4.550000e+00
# gsat_BestSolution_Mean                 2.817500e+03  1.192840e+05
# gsat_BestSolution_CoeffVariance        6.127750e-02  2.831170e-01
# gsat_FirstLocalMinStep_Mean            4.210770e+02  4.938310e+03
# gsat_FirstLocalMinStep_CoeffVariance   7.381090e-03  5.245970e-02
# gsat_FirstLocalMinStep_Median          4.280000e+02  5.181250e+03
# gsat_BestAvgImprovement_Mean           2.331460e+00  9.417840e+00
# gsat_BestAvgImprovement_CoeffVariance  2.352050e-01  6.402870e-01
# gsat_FirstLocalMinRatio_Mean           9.989690e-01  1.560400e+00
# gsat_FirstLocalMinRatio_CoeffVariance  3.742900e-03  3.105195e-02
# ls_gsat_featuretime                    2.720000e+00  4.570000e+00
# lobjois_mean_depth_over_vars           1.616576e-01  3.254087e-01
# lobjois_log_num_nodes_over_vars        3.844047e-01  6.394696e-01
# lobjois_featuretime                    2.000000e+00  2.120000e+00
# saps_FirstLocalMinStep_Q_10            0.000000e+00  5.165000e+02
# saps_FirstLocalMinStep_Q_90            0.000000e+00  8.380000e+02
# gsat_FirstLocalMinStep_Q_10            5.600000e+01  1.261500e+03
# gsat_FirstLocalMinStep_Q_90            3.290000e+02  4.384500e+03
#
#                                                 max
# clauses                                8.730200e+08
# variables                              2.886922e+07
# clause_size_1                          8.876720e+05
# clause_size_2                          8.785615e+08
# clause_size_3                          9.399184e+07
# clause_size_4                          1.469232e+07
# clause_size_5                          1.572861e+07
# clause_size_6                          7.674150e+06
# clause_size_7                          6.896240e+05
# clause_size_8                          3.279193e+09
# clause_size_9                          3.178287e+06
# horn_clauses                           1.614921e+08
# inv_horn_clauses                       8.730144e+08
# positive_clauses                       8.587380e+06
# negative_clauses                       8.713977e+08
# horn_vars_mean                         1.023244e+05
# horn_vars_variance                     7.651367e+09
# horn_vars_max                          2.252270e+05
# horn_vars_entropy                      8.976864e+00
# inv_horn_vars_mean                     3.010464e+04
# inv_horn_vars_variance                 1.073943e+09
# inv_horn_vars_max                      2.621440e+05
# inv_horn_vars_entropy                  9.211690e+00
# balance_clause_mean                    6.996871e+01
# balance_clause_variance                4.513781e+04
# balance_clause_min                     6.000000e+00
# balance_clause_max                     2.076060e+05
# balance_clause_entropy                 3.916986e+00
# vcg_vdegrees_mean                      9.938659e-01
# vcg_vdegrees_variance                  3.409131e-01
# vcg_vdegrees_max                       1.000000e+00
# vcg_vdegrees_entropy                   3.071735e+00
# vcg_cdegrees_mean                      9.999996e-01
# vcg_cdegrees_variance                  9.260255e-01
# vcg_cdegrees_max                       1.000000e+00
# vcg_cdegrees_entropy                   3.253313e+00
# vg_degrees_mean                        1.101055e+05
# vg_degrees_variance                    7.154115e+09
# vg_degrees_max                         5.242880e+05
# vg_degrees_entropy                     9.211690e+00
# cg_degrees_mean                        8.301289e+05
# cg_degrees_variance                    1.326953e+11
# cg_degrees_min                         1.064000e+03
# cg_degrees_max                         1.350476e+08
# cg_degrees_entropy                     1.148299e+01
# base_features_runtime                  3.220000e+02
# n_vars                                 2.886922e+07
# n_gates                                2.424489e+06
# n_roots                                8.876720e+05
# n_none                                 2.886782e+07
# n_generic                              1.188710e+05
# n_mono                                 2.304063e+06
# n_and                                  5.509590e+05
# n_or                                   6.197780e+05
# n_triv                                 4.505600e+04
# n_equiv                                1.308170e+05
# n_full                                 1.293000e+03
# levels_mean                            2.421506e+04
# levels_variance                        3.585529e+08
# levels_max                             5.996000e+04
# levels_entropy                         1.405317e+01
# levels_generic_mean                    1.025000e+03
# levels_generic_variance                8.109095e+04
# levels_generic_min                     1.025000e+03
# levels_generic_max                     1.376000e+03
# levels_generic_entropy                 8.716159e+00
# levels_mono_mean                       2.998060e+04
# levels_mono_variance                   2.995639e+08
# levels_mono_min                        1.000000e+00
# levels_mono_max                        5.996000e+04
# levels_mono_entropy                    1.588250e+01
# levels_and_mean                        1.499650e+04
# levels_and_variance                    1.948534e+08
# levels_and_min                         5.150000e+02
# levels_and_max                         5.188000e+04
# levels_and_entropy                     1.470056e+01
# levels_or_mean                         1.499130e+04
# levels_or_variance                     2.221521e+08
# levels_or_min                          5.140000e+02
# levels_or_max                          5.188000e+04
# levels_or_entropy                      1.479313e+01
# levels_triv_mean                       2.169863e+01
# levels_triv_variance                   1.816815e+02
# levels_triv_min                        8.000000e+00
# levels_triv_max                        5.500000e+01
# levels_triv_entropy                    4.742931e+00
# levels_equiv_mean                      2.394150e+04
# levels_equiv_variance                  8.132914e+06
# levels_equiv_min                       2.394100e+04
# levels_equiv_max                       2.394200e+04
# levels_equiv_entropy                   1.327137e+01
# levels_full_mean                       4.753905e+01
# levels_full_variance                   7.117381e+02
# levels_full_min                        3.000000e+00
# levels_full_max                        9.500000e+01
# levels_full_entropy                    6.553419e+00
# gate_features_runtime                  9.870000e+02
# nvarsOrig                              3.142183e+06
# nclausesOrig                           4.274785e+07
# nvars                                  1.315598e+06
# nclauses                               3.574171e+07
# reducedVars                            1.808887e+02
# reducedClauses                         1.447900e+02
# Pre_featuretime                        1.163360e+03
# vars_clauses_ratio                     4.734043e-01
# POSNEG_RATIO_CLAUSE_mean               1.000000e+00
# POSNEG_RATIO_CLAUSE_coeff_variation    1.016631e+01
# POSNEG_RATIO_CLAUSE_min                1.000000e+00
# POSNEG_RATIO_CLAUSE_max                1.000000e+00
# POSNEG_RATIO_CLAUSE_entropy            2.587890e+00
# VCG_CLAUSE_mean                        2.820513e-01
# VCG_CLAUSE_coeff_variation             6.438505e+01
# VCG_CLAUSE_min                         1.538462e-01
# VCG_CLAUSE_max                         6.799220e-01
# VCG_CLAUSE_entropy                     2.347760e+00
# UNARY                                  0.000000e+00
# BINARYplus                             9.984412e-01
# TRINARYplus                            1.000000e+00
# Basic_featuretime                      5.940000e+00
# VCG_VAR_mean                           2.820513e-01
# VCG_VAR_coeff_variation                2.909460e+01
# VCG_VAR_min                            1.538462e-01
# VCG_VAR_max                            4.102564e-01
# VCG_VAR_entropy                        7.198539e+00
# POSNEG_RATIO_VAR_mean                  9.949336e-01
# POSNEG_RATIO_VAR_stdev                 4.666205e-01
# POSNEG_RATIO_VAR_min                   9.849624e-01
# POSNEG_RATIO_VAR_max                   1.000000e+00
# POSNEG_RATIO_VAR_entropy               4.292295e+00
# HORNY_VAR_mean                         1.600000e-01
# HORNY_VAR_coeff_variation              4.050415e+01
# HORNY_VAR_min                          1.333333e-01
# HORNY_VAR_max                          2.307692e-01
# HORNY_VAR_entropy                      6.796619e+00
# horn_clauses_fraction                  9.996877e-01
# VG_mean                                2.840237e-01
# VG_coeff_variation                     1.597186e+01
# VG_min                                 2.564103e-01
# VG_max                                 3.076923e-01
# KLB_featuretime                        4.784740e+03
# CG_mean                                4.063116e-01
# CG_coeff_variation                     8.042849e+00
# CG_min                                 1.794872e-01
# CG_max                                 9.073317e-01
# CG_entropy                             5.403699e+00
# cluster_coeff_mean                     5.193683e-01
# cluster_coeff_coeff_variation          1.230729e+00
# cluster_coeff_min                      4.202899e-01
# cluster_coeff_max                      8.888889e-01
# cluster_coeff_entropy                  4.082349e+00
# CG_featuretime                         4.922940e+03
# DIAMETER_mean                          1.987267e+04
# DIAMETER_coeff_variation               3.646244e-01
# DIAMETER_min                           1.975900e+04
# DIAMETER_max                           1.998600e+04
# DIAMETER_entropy                       5.468720e+00
# DIAMETER_featuretime                   2.540000e+01
# cl_num_mean                            4.900000e+03
# cl_num_coeff_variation                 2.323127e+00
# cl_num_min                             4.886000e+03
# cl_num_max                             4.921000e+03
# cl_num_q90                             4.921000e+03
# cl_num_q10                             4.886000e+03
# cl_num_q75                             4.921000e+03
# cl_num_q25                             4.896000e+03
# cl_num_q50                             4.902000e+03
# cl_size_mean                           2.255873e+03
# cl_size_coeff_variation                4.015396e+00
# cl_size_min                            3.933249e+02
# cl_size_max                            7.983000e+03
# cl_size_q90                            7.983000e+03
# cl_size_q10                            3.933249e+02
# cl_size_q75                            4.163000e+03
# cl_size_q25                            3.933249e+02
# cl_size_q50                            2.608000e+03
# cl_featuretime                         2.120000e+00
# SP_bias_mean                           9.941925e-01
# SP_bias_coeff_variation                4.702701e+00
# SP_bias_min                            9.143900e-01
# SP_bias_max                            1.000000e+00
# SP_bias_q90                            1.000000e+00
# SP_bias_q10                            9.989084e-01
# SP_bias_q75                            1.000000e+00
# SP_bias_q25                            1.000000e+00
# SP_bias_q50                            1.000000e+00
# SP_unconstraint_mean                   4.998976e-01
# SP_unconstraint_coeff_variation        5.496301e+01
# SP_unconstraint_min                    3.830613e-01
# SP_unconstraint_max                    1.000000e+00
# SP_unconstraint_q90                    1.000000e+00
# SP_unconstraint_q10                    4.995112e-01
# SP_unconstraint_q75                    5.000000e-01
# SP_unconstraint_q25                    5.000000e-01
# SP_unconstraint_q50                    5.000000e-01
# sp_featuretime                         3.320120e+03
# vars_reduced_depth_1                   6.926910e-01
# vars_reduced_depth_4                   9.063540e-01
# vars_reduced_depth_16                  9.929695e-01
# vars_reduced_depth_64                  9.990006e-01
# vars_reduced_depth_256                 9.990006e-01
# unit_featuretime                       2.798820e+03
# LP_OBJ                                 2.167579e+01
# LPSLack_mean                           5.000000e-01
# LPSLack_coeff_variation                1.050397e+01
# LPSLack_min                            5.000000e-01
# LPSLack_max                            5.000000e-01
# lpIntRatio                             9.910180e-01
# lpTIME                                 4.893360e+03
# saps_BestSolution_Mean                 8.851060e+06
# saps_BestSolution_CoeffVariance        1.402720e+01
# saps_FirstLocalMinStep_Mean            2.194500e+04
# saps_FirstLocalMinStep_CoeffVariance   1.414210e+00
# saps_FirstLocalMinStep_Median          2.194500e+04
# saps_BestAvgImprovement_Mean           1.937920e+04
# saps_BestAvgImprovement_CoeffVariance  2.802100e+00
# saps_FirstLocalMinRatio_Mean           1.240900e+04
# saps_FirstLocalMinRatio_CoeffVariance  2.820120e+00
# ls_saps_featuretime                    2.956000e+01
# gsat_BestSolution_Mean                 8.654980e+06
# gsat_BestSolution_CoeffVariance        1.719980e+01
# gsat_FirstLocalMinStep_Mean            7.831600e+04
# gsat_FirstLocalMinStep_CoeffVariance   1.414210e+00
# gsat_FirstLocalMinStep_Median          7.831600e+04
# gsat_BestAvgImprovement_Mean           2.615060e+03
# gsat_BestAvgImprovement_CoeffVariance  3.501660e+00
# gsat_FirstLocalMinRatio_Mean           1.361780e+03
# gsat_FirstLocalMinRatio_CoeffVariance  3.994750e+00
# ls_gsat_featuretime                    2.800000e+01
# lobjois_mean_depth_over_vars           9.889525e-01
# lobjois_log_num_nodes_over_vars        9.999608e-01
# lobjois_featuretime                    1.950100e+03
# saps_FirstLocalMinStep_Q_10            2.194500e+04
# saps_FirstLocalMinStep_Q_90            2.194500e+04
# gsat_FirstLocalMinStep_Q_10            7.831600e+04
# gsat_FirstLocalMinStep_Q_90            7.831600e+04

# %% [markdown]
# ### Runtime statistics

# %%
(
    runtimes_df[col_name].replace([np.inf, -np.inf], 5000).mean(),
    runtimes_df[col_name].replace([np.inf, -np.inf], 5000).sum() / (60 * 60 * 24)
)
# Out:
# (2320.5467300079176, 67.84376203703704)

# %%
stats_per_column = []
for col_name in runtimes_df.columns:
    stats_per_column.append(runtimes_df[col_name].replace([np.inf, -np.inf], np.nan).dropna().describe())

pd.concat(stats_per_column, axis=1).transpose()
# Out:
#                        count         mean          std  min      25%     50%  \
# cadical_elimfalse     1395.0  1122.377412  1351.740051  0.0   73.935  520.77
# cadical               1457.0  1023.487152  1264.863799  0.0   73.590  432.39
# cadical_pripro        1519.0  1062.638604  1274.895322  0.0   77.380  473.47
# cadical_stability     1428.0  1077.792353  1296.114002  0.0   85.365  470.87
# candy                 1075.0  1057.430335  1310.362463  0.0   50.340  417.69
# glucose_chanseok      1137.0   865.786438  1180.425752  0.0   34.180  286.97
# glucose               1161.0   923.262274  1241.815299  0.0   43.990  298.47
# glucose_var_decay099  1100.0   933.588682  1234.385008  0.0   34.715  311.73
# kissat                1660.0   791.072169  1106.216364  0.0   51.465  268.53
# lingeling             1229.0   956.540529  1235.901952  0.0   71.080  346.27
# minisat                871.0   717.714948  1057.016479  0.0   22.790  273.38
# relaxed               1525.0   961.160702  1189.909168  0.0  112.690  422.87
# yalsat                 107.0   552.379439  1083.719296  0.0    0.400   25.19
# slime                 1504.0   905.317487  1134.596164  0.0   99.040  435.22
# kissat_sweep          1655.0   770.931782  1088.761960  0.0   51.030  262.47
# lstech_maple          1627.0   840.012932  1113.607438  0.0   60.790  343.26
#
#                             75%      max
# cadical_elimfalse     1853.8400  4987.05
# cadical               1515.4400  4969.39
# cadical_pripro        1739.0400  4960.34
# cadical_stability     1710.8950  4991.42
# candy                 1644.8850  4993.22
# glucose_chanseok      1270.8000  4996.45
# glucose               1412.5500  4995.01
# glucose_var_decay099  1458.3825  4972.54
# kissat                1053.6150  4997.29
# lingeling             1457.5200  4974.17
# minisat                832.5400  4991.41
# relaxed               1359.1100  4972.04
# yalsat                 505.5600  4678.24
# slime                 1258.4725  4993.74
# kissat_sweep          1040.9850  4998.91
# lstech_maple          1132.0900  4975.19

# %% [markdown]
# ### PAR-2 Score

# %%
pd.DataFrame.from_records(list(sorted(zip(
    runtimes_df.columns,
    np.mean(runtimes_df.replace(np.inf, 10000), axis=0)
), key=lambda x: x[1])), columns=["Algorithm", "PAR-2 score"]).set_index("Algorithm", drop=True)
# Out:
#                       PAR-2 score
# Algorithm
# kissat                3948.210530
# kissat_sweep          3953.243112
# lstech_maple          4100.040000
# relaxed               4543.060202
# slime                 4584.955463
# cadical_pripro        4625.553460
# cadical               4822.336017
# cadical_stability     4956.091639
# cadical_elimfalse     5097.274937
# lingeling             5599.995372
# glucose               5828.150238
# glucose_chanseok      5888.519074
# glucose_var_decay099  6051.839885
# candy                 6194.274588
# minisat               6799.338765
# yalsat                9599.803880

# %% [markdown]
# ### Save data

# %%
np.all(base_features_df.index == meta_df.index), base_features_df.shape, meta_df.shape
# Out:
# (True, (29358, 46), (29358, 9))

# %%
import pickle

with open("./pickled-data/meta_df.pkl", "wb") as file:
    pickle.dump(meta_df.copy(), file)
with open("./pickled-data/base_features_df.pkl", "wb") as file:
    pickle.dump(base_features_df.copy(), file)

# %%
import pickle

with open("./pickled-data/meta_df.pkl", "wb") as file:
    pickle.dump(meta_df, file)
with open("./pickled-data/base_features_df.pkl", "wb") as file:
    pickle.dump(base_features_df, file)
with open("./pickled-data/features_df.pkl", "wb") as file:
    pickle.dump(features_df, file)
with open("./pickled-data/features_satzilla_df.pkl", "wb") as file:
    pickle.dump(features_satzilla_df, file)
with open("./pickled-data/runtimes_df.pkl", "wb") as file:
    pickle.dump(runtimes_df, file)

# %% [markdown]
# ## SAT 2020 and 2021 Main Track Filters

# %%
import pickle
import numpy as np
import pandas as pd

from gbd_tool.gbd_api import GBD
    
# Meta-data dataframe
instance_filter_sat_2020 = "track=main_2020"
instance_filter_sat_2021 = "track=main_2021"
with GBD(["gbd-data/meta.db"]) as gbd:
    features = gbd.get_features()
    features.remove("hash")
    sat2020_meta_df = pd.DataFrame.from_records(
        gbd.query_search(instance_filter_sat_2020, resolve=features),
        columns=gbd.get_features())
    sat2021_meta_df = pd.DataFrame.from_records(
        gbd.query_search(instance_filter_sat_2021, resolve=features),
        columns=gbd.get_features())
    
main_sat_2020_hashes = sat2020_meta_df["hash"].copy()
main_sat_2021_hashes = sat2021_meta_df["hash"].copy()
main_sat_2020_hashes.shape, main_sat_2021_hashes.shape
# Out:
# ((400,), (400,))

# %%
with open("./pickled-data/runtimes_df.pkl", "rb") as file:
    runtimes_df = pickle.load(file)
    
sat_202x_submission_hashes = runtimes_df.index.to_series(index=range(runtimes_df.shape[0]))
sat_202x_submission_hashes.shape
# Out:
# (2526,)

# %%
import pickle

with open("./pickled-data/instance_filters/main_sat_2020_hashes.pkl", "wb") as file:
    pickle.dump(main_sat_2020_hashes, file)
with open("./pickled-data/instance_filters/main_sat_2021_hashes.pkl", "wb") as file:
    pickle.dump(main_sat_2021_hashes, file)
with open("./pickled-data/instance_filters/sat_202x_submission_hashes.pkl", "wb") as file:
    pickle.dump(sat_202x_submission_hashes, file)

# %% [markdown]
# ## SAT Competition 2020 / 2021 all solver runtimes

# %%
# Dataframe with all runtimes for SAT2020
with GBD(["gbd-data/meta.db", "gbd-data/sc2020.db"]) as gbd:
    features = gbd.get_features()
    for meta_feat in gbd.get_features(dbname="meta_db"):
        features.remove(meta_feat)
    features_with_hash = features.copy()
    features_with_hash.insert(0, "hash")
    runtimes_sc2020_df = pd.DataFrame.from_records(
        gbd.query_search(instance_filter_expr, resolve=features),
        columns=features_with_hash)
    
counts = {}
for col_name in runtimes_sc2020_df.columns:
    if col_name == "hash":
        runtimes_sc2020_df[col_name] = runtimes_sc2020_df[col_name].astype("string")
    else:
        runtimes_sc2020_df[col_name] = runtimes_sc2020_df[col_name].map(convert_value)  
runtimes_sc2020_df.set_index("hash", inplace=True, drop=True)

runtimes_sc2020_df = runtimes_sc2020_df.loc[main_sat_2020_hashes, :]
runtimes_sc2020_df
# Out:
#                                   cadical_sc2020  duriansat  exmaple_padc_dl  \
# hash
# 0151bedac526ee195bc52e4134cd80e7       4582.5600        inf              inf
# 0241f35c5752768d2b0580533d143a14             inf        inf          453.851
# 024af9416f8c1dad1b4f974757e38d51             inf        inf              inf
# 02627689047d06fbb642eef14768d751         90.3281    80.8298              inf
# 02c6fe8483e4f4474b7ac9731772535d       1026.8200   488.5130         1650.670
# ...                                          ...        ...              ...
# fc538412229f86bc7016b8bc0aca3924        859.2300   566.8060          593.555
# fc794887d3aede5fdd422a501f730032        777.9920   711.0130          722.969
# fee70cede2b5b55bfbdb6e48fbe7ce4f           905.467
# ff0d5cb434081622290325ab3ed57fd7          2708.810
#
# [400 rows x 43 columns]

# %%
np.count_nonzero(np.isnan(runtimes_sc2020_df))
# Out:
# 0

# %%
pd.DataFrame.from_records(list(sorted(zip(
    runtimes_sc2020_df.columns,
    np.mean(runtimes_sc2020_df.replace(np.inf, 10000), axis=0)
), key=lambda x: x[1])), columns=["Algorithm", "PAR-2 score"]).set_index("Algorithm", drop=True)
# Out:
#                             PAR-2 score
# Algorithm
# kissat_sat                  3926.191198
# kissat                      4070.237330
# cryptominisat_ccnr_lsids    4249.319692
# cryptominisat_ccnr          4260.106620
# cadical_alluip_trail        4428.149656
# cadical_alluip              4429.598133
# cryptominisat_walksat       4483.774581
# cadical_trail               4554.032149
# kissat_unsat                4560.038505
# cadical_sc2020              4607.639859
# maple_dl_f2trc              5115.690163
# undominated                 5115.863237
# exmaple_padc_dl             5132.746635
# duriansat                   5150.694764
# maple_f2trc                 5153.245003
# maple_f2trc_s               5167.667730
# maplelcmdistchronobt_dl_v3  5216.187415
# exmaple_padc_dl_ovau_lin    5234.189015
# maple_simp                  5272.317249
# maple_scavel                5321.320231
# maple_mix                   5341.450132
# exmaple_padc_dl_ovau_exp    5347.010870
# maple_scavel01              5425.637017
# exp_v_mld_cbt_dl            5463.204953
# maplecomsps_lrb_vsids_2     5476.144283
# maple_lrb_vsids_2_init      5486.190024
# maple_scavel02              5497.929855
# maple_cm_dist_sattime2s     5514.545937
# maple_alluip_trail          5558.002427
# exp_v_lgb_mld_cbt_dl        5620.409608
# exp_v_l_mld_cbt_dl          5705.213508
# exp_l_mld_cbt_dl            5715.004005
# maple_cmused_dist           5717.378417
# maple_cm_dist               5780.504425
# maple_cm_dist_simp2         5809.272442
# upglucose_3_padc            6630.965559
# glucose3                    6662.977901
# parafrost_cbt               6933.951767
# undominated_top36           7022.893864
# undominated_top16           7023.059893
# undominated_top24           7023.542335
# parafrost                   7073.972012
# pausat                      9469.041088

# %%
# Dataframe with all runtimes for SAT2021
with GBD(["gbd-data/meta.db", "gbd-data/sc2021.db"]) as gbd:
    features = gbd.get_features()
    for meta_feat in gbd.get_features(dbname="meta_db"):
        features.remove(meta_feat)
    features_with_hash = features.copy()
    features_with_hash.insert(0, "hash")
    runtimes_sc2021_df = pd.DataFrame.from_records(
        gbd.query_search(instance_filter_expr, resolve=features),
        columns=features_with_hash)
    
counts = {}
for col_name in runtimes_sc2021_df.columns:
    if col_name == "hash":
        runtimes_sc2021_df[col_name] = runtimes_sc2021_df[col_name].astype("string")
    else:
        runtimes_sc2021_df[col_name] = runtimes_sc2021_df[col_name].map(convert_value)  
runtimes_sc2021_df.set_index("hash", inplace=True, drop=True)

runtimes_sc2021_df = runtimes_sc2021_df.loc[main_sat_2021_hashes, :]
runtimes_sc2021_df
# Out:
#                                   cadical_hack_gb  CaDiCaL_PriPro  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64          22.4347         9.00577
# 0041051c73dcdd885d412a38e8b09fba        1488.0000      1016.00000
# 004b0f451f7d96f6a572e9e76360f51a         261.4790       673.59000
# 0107f34364dfff8ab062193b2c71b4de         235.7030       242.10600
# 01135f7a79d555bd0406f00fac22cbe2              inf             inf
# ...                                           ...             ...
# fab5698f06861b62c881c77630fbcd4d        1130.6300      1304.93000
# faea4b579b0010b32f001ac4b5b9415a              inf             inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b         896.6090       909.41000
# fdfd5975c57d7cd2264ef6aff6cb4815         787.8260      1648.71000
# ff4b033c2a2da4100f0b1e83c49c5f80              inf      4535.82000
#
#                                   CaDiCaL_PriPro_no_bin  CaDiCaL_rp  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64                 9.0832     107.783
# 0041051c73dcdd885d412a38e8b09fba              1022.7700     971.375
# 004b0f451f7d96f6a572e9e76360f51a               669.4300     974.224
# 0107f34364dfff8ab062193b2c71b4de               248.0670     248.634
# 01135f7a79d555bd0406f00fac22cbe2                    inf         inf
# ...                                                 ...         ...
# fab5698f06861b62c881c77630fbcd4d              1287.2000     518.023
# faea4b579b0010b32f001ac4b5b9415a                    inf         inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b               928.9420     833.987
# fdfd5975c57d7cd2264ef6aff6cb4815              1664.8300     162.951
# ff4b033c2a2da4100f0b1e83c49c5f80              4533.6600     903.868
#
#                                   CaDiCaL_sc2021  Cadical_SCAVEL01  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64         95.9904           104.243
# 0041051c73dcdd885d412a38e8b09fba        201.6360           615.676
# 004b0f451f7d96f6a572e9e76360f51a        111.5200           409.269
# 0107f34364dfff8ab062193b2c71b4de         93.7477           272.363
# 01135f7a79d555bd0406f00fac22cbe2             inf               inf
# ...                                          ...               ...
# fab5698f06861b62c881c77630fbcd4d        404.5060          1049.650
# faea4b579b0010b32f001ac4b5b9415a       1026.5200          3539.150
# fb621b2b4a54ec0f01ac36daaa7f0f5b        699.4920           757.696
# fdfd5975c57d7cd2264ef6aff6cb4815        654.6210               inf
# ff4b033c2a2da4100f0b1e83c49c5f80             inf               inf
#
#                                   Cadical_SCAVEL02  CaDiCaL_Stability_HC  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64           50.2382                99.731
# 0041051c73dcdd885d412a38e8b09fba          413.0990              1066.010
# 004b0f451f7d96f6a572e9e76360f51a          201.8600                   inf
# 0107f34364dfff8ab062193b2c71b4de          358.3750               234.599
# 01135f7a79d555bd0406f00fac22cbe2               inf                   inf
# ...                                            ...                   ...
# fab5698f06861b62c881c77630fbcd4d         1949.6900              1408.120
# faea4b579b0010b32f001ac4b5b9415a         1760.2400                   inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b         2469.9700              1447.820
# fdfd5975c57d7cd2264ef6aff6cb4815          383.6190              1179.210
# ff4b033c2a2da4100f0b1e83c49c5f80               inf                   inf
#
#                                   cadical_watch_sat  CleanMaple  ...  \
# hash                                                             ...
# 000a41cdca43be89ed62ea3abf2d0b64            34.0304     376.825  ...
# 0041051c73dcdd885d412a38e8b09fba           894.6310         inf  ...
# 004b0f451f7d96f6a572e9e76360f51a           117.1340    1465.810  ...
# 0107f34364dfff8ab062193b2c71b4de           256.9330    1536.320  ...
# 01135f7a79d555bd0406f00fac22cbe2                inf         inf  ...
# ...                                             ...         ...  ...
# fab5698f06861b62c881c77630fbcd4d          1101.9900    4983.770  ...
# faea4b579b0010b32f001ac4b5b9415a                inf         inf  ...
# fb621b2b4a54ec0f01ac36daaa7f0f5b           884.2750         inf  ...
# fdfd5975c57d7cd2264ef6aff6cb4815           628.9400         inf  ...
# ff4b033c2a2da4100f0b1e83c49c5f80            99.7583         inf  ...
#
#                                   Relaxed_LCFTP  Relaxed_LCFTP_V2  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64       77.78450          38.84350
# 0041051c73dcdd885d412a38e8b09fba            inf               inf
# 004b0f451f7d96f6a572e9e76360f51a       53.73250         404.90100
# 0107f34364dfff8ab062193b2c71b4de      362.16500        1180.00000
# 01135f7a79d555bd0406f00fac22cbe2            inf               inf
# ...                                         ...               ...
# fab5698f06861b62c881c77630fbcd4d      783.30400        1004.99000
# faea4b579b0010b32f001ac4b5b9415a            inf               inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b            inf               inf
# fdfd5975c57d7cd2264ef6aff6cb4815        3.27364           1.66648
# ff4b033c2a2da4100f0b1e83c49c5f80      693.50400        4167.05000
#
#                                   Relaxed_LCFTP_V3  Relaxed_LCMDCBDL_BLB  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64          37.95730              38.17060
# 0041051c73dcdd885d412a38e8b09fba               inf                   inf
# 004b0f451f7d96f6a572e9e76360f51a         349.05100            1206.83000
# 0107f34364dfff8ab062193b2c71b4de         402.26200             178.38400
# 01135f7a79d555bd0406f00fac22cbe2               inf                   inf
# ...                                            ...                   ...
# fab5698f06861b62c881c77630fbcd4d         599.72000            1053.28000
# faea4b579b0010b32f001ac4b5b9415a               inf                   inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b               inf                   inf
# fdfd5975c57d7cd2264ef6aff6cb4815           1.67961               1.66494
# ff4b033c2a2da4100f0b1e83c49c5f80        3229.07000            1020.58000
#
#                                   Relaxed_LCMDCBDL_SCAVEL01  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64                    38.9252
# 0041051c73dcdd885d412a38e8b09fba                        inf
# 004b0f451f7d96f6a572e9e76360f51a                   113.4300
# 0107f34364dfff8ab062193b2c71b4de                   201.6650
# 01135f7a79d555bd0406f00fac22cbe2                        inf
# ...                                                     ...
# fab5698f06861b62c881c77630fbcd4d                   906.1090
# faea4b579b0010b32f001ac4b5b9415a                        inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b                        inf
# fdfd5975c57d7cd2264ef6aff6cb4815                     1.6671
# ff4b033c2a2da4100f0b1e83c49c5f80                   763.4290
#
#                                   Relaxed_LCMDCBDL_SCAVEL02  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64                    106.709
# 0041051c73dcdd885d412a38e8b09fba                        inf
# 004b0f451f7d96f6a572e9e76360f51a                    188.559
# 0107f34364dfff8ab062193b2c71b4de                    811.956
# 01135f7a79d555bd0406f00fac22cbe2                        inf
# ...                                                     ...
# fab5698f06861b62c881c77630fbcd4d                   1039.450
# faea4b579b0010b32f001ac4b5b9415a                        inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b                   4346.810
# fdfd5975c57d7cd2264ef6aff6cb4815                    599.829
# ff4b033c2a2da4100f0b1e83c49c5f80                        inf
#
#                                   SLIME_hess_no_rnd  SLIME_hess_rnd  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64           86.87150       105.98600
# 0041051c73dcdd885d412a38e8b09fba                inf             inf
# 004b0f451f7d96f6a572e9e76360f51a          271.41900       542.56400
# 0107f34364dfff8ab062193b2c71b4de          293.24000       233.12800
# 01135f7a79d555bd0406f00fac22cbe2                inf             inf
# ...                                             ...             ...
# fab5698f06861b62c881c77630fbcd4d         1063.55000       787.87100
# faea4b579b0010b32f001ac4b5b9415a                inf             inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b                inf             inf
# fdfd5975c57d7cd2264ef6aff6cb4815            1.37041         1.37125
# ff4b033c2a2da4100f0b1e83c49c5f80          903.73200      2259.23000
#
#                                   SLIME_no_hess_no_rnd  SLIME_no_hess_rnd
# hash
# 000a41cdca43be89ed62ea3abf2d0b64              89.22070           40.43220
# 0041051c73dcdd885d412a38e8b09fba                   inf                inf
# 004b0f451f7d96f6a572e9e76360f51a             267.06500           73.44250
# 0107f34364dfff8ab062193b2c71b4de             203.81800          179.98100
# 01135f7a79d555bd0406f00fac22cbe2                   inf                inf
# ...                                                ...                ...
# fab5698f06861b62c881c77630fbcd4d             565.02300          789.02600
# faea4b579b0010b32f001ac4b5b9415a                   inf                inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b                   inf                inf
# fdfd5975c57d7cd2264ef6aff6cb4815               1.37725            1.37077
# ff4b033c2a2da4100f0b1e83c49c5f80            1293.48000                inf
#
# [400 rows x 46 columns]

# %%
counts
# Out:
# {'unverified': 304, 'memout': 1}

# %%
runtimes_sc2021_df = runtimes_sc2021_df.loc[:, ~np.any(np.isnan(runtimes_sc2021_df), axis=0)]
runtimes_sc2021_df
# Out:
#                                   cadical_hack_gb  CaDiCaL_PriPro  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64          22.4347         9.00577
# 0041051c73dcdd885d412a38e8b09fba        1488.0000      1016.00000
# 004b0f451f7d96f6a572e9e76360f51a         261.4790       673.59000
# 0107f34364dfff8ab062193b2c71b4de         235.7030       242.10600
# 01135f7a79d555bd0406f00fac22cbe2              inf             inf
# ...                                           ...             ...
# fab5698f06861b62c881c77630fbcd4d        1130.6300      1304.93000
# faea4b579b0010b32f001ac4b5b9415a              inf             inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b         896.6090       909.41000
# fdfd5975c57d7cd2264ef6aff6cb4815         787.8260      1648.71000
# ff4b033c2a2da4100f0b1e83c49c5f80              inf      4535.82000
#
#                                   CaDiCaL_PriPro_no_bin  CaDiCaL_rp  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64                 9.0832     107.783
# 0041051c73dcdd885d412a38e8b09fba              1022.7700     971.375
# 004b0f451f7d96f6a572e9e76360f51a               669.4300     974.224
# 0107f34364dfff8ab062193b2c71b4de               248.0670     248.634
# 01135f7a79d555bd0406f00fac22cbe2                    inf         inf
# ...                                                 ...         ...
# fab5698f06861b62c881c77630fbcd4d              1287.2000     518.023
# faea4b579b0010b32f001ac4b5b9415a                    inf         inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b               928.9420     833.987
# fdfd5975c57d7cd2264ef6aff6cb4815              1664.8300     162.951
# ff4b033c2a2da4100f0b1e83c49c5f80              4533.6600     903.868
#
#                                   CaDiCaL_sc2021  Cadical_SCAVEL01  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64         95.9904           104.243
# 0041051c73dcdd885d412a38e8b09fba        201.6360           615.676
# 004b0f451f7d96f6a572e9e76360f51a        111.5200           409.269
# 0107f34364dfff8ab062193b2c71b4de         93.7477           272.363
# 01135f7a79d555bd0406f00fac22cbe2             inf               inf
# ...                                          ...               ...
# fab5698f06861b62c881c77630fbcd4d        404.5060          1049.650
# faea4b579b0010b32f001ac4b5b9415a       1026.5200          3539.150
# fb621b2b4a54ec0f01ac36daaa7f0f5b        699.4920           757.696
# fdfd5975c57d7cd2264ef6aff6cb4815        654.6210               inf
# ff4b033c2a2da4100f0b1e83c49c5f80             inf               inf
#
#                                   Cadical_SCAVEL02  CaDiCaL_Stability_HC  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64           50.2382                99.731
# 0041051c73dcdd885d412a38e8b09fba          413.0990              1066.010
# 004b0f451f7d96f6a572e9e76360f51a          201.8600                   inf
# 0107f34364dfff8ab062193b2c71b4de          358.3750               234.599
# 01135f7a79d555bd0406f00fac22cbe2               inf                   inf
# ...                                            ...                   ...
# fab5698f06861b62c881c77630fbcd4d         1949.6900              1408.120
# faea4b579b0010b32f001ac4b5b9415a         1760.2400                   inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b         2469.9700              1447.820
# fdfd5975c57d7cd2264ef6aff6cb4815          383.6190              1179.210
# ff4b033c2a2da4100f0b1e83c49c5f80               inf                   inf
#
#                                   cadical_watch_sat  cms_expV_gbL  ...  \
# hash                                                               ...
# 000a41cdca43be89ed62ea3abf2d0b64            34.0304       8.12578  ...
# 0041051c73dcdd885d412a38e8b09fba           894.6310    2125.28000  ...
# 004b0f451f7d96f6a572e9e76360f51a           117.1340     351.15800  ...
# 0107f34364dfff8ab062193b2c71b4de           256.9330     112.17600  ...
# 01135f7a79d555bd0406f00fac22cbe2                inf           inf  ...
# ...                                             ...           ...  ...
# fab5698f06861b62c881c77630fbcd4d          1101.9900    4261.81000  ...
# faea4b579b0010b32f001ac4b5b9415a                inf           inf  ...
# fb621b2b4a54ec0f01ac36daaa7f0f5b           884.2750           inf  ...
# fdfd5975c57d7cd2264ef6aff6cb4815           628.9400      41.06550  ...
# ff4b033c2a2da4100f0b1e83c49c5f80            99.7583     822.83100  ...
#
#                                   Kissat_sc2021_sweep  Maple_simp21  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64              21.1697       16.6443
# 0041051c73dcdd885d412a38e8b09fba             286.2280           inf
# 004b0f451f7d96f6a572e9e76360f51a             779.4800       83.7475
# 0107f34364dfff8ab062193b2c71b4de              73.0500      169.8680
# 01135f7a79d555bd0406f00fac22cbe2                  inf           inf
# ...                                               ...           ...
# fab5698f06861b62c881c77630fbcd4d             285.6180      502.0150
# faea4b579b0010b32f001ac4b5b9415a            1577.5000           inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b            2017.2200           inf
# fdfd5975c57d7cd2264ef6aff6cb4815            1595.7700      121.4770
# ff4b033c2a2da4100f0b1e83c49c5f80             164.7460           inf
#
#                                   optsat_m21  optsat_R21    ParaFROST  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64     37.9729     36.5867   121.262000
# 0041051c73dcdd885d412a38e8b09fba         inf         inf   879.623000
# 004b0f451f7d96f6a572e9e76360f51a     85.7536     84.9290    60.118400
# 0107f34364dfff8ab062193b2c71b4de    169.2850    153.2350   172.471000
# 01135f7a79d555bd0406f00fac22cbe2         inf         inf          inf
# ...                                      ...         ...          ...
# fab5698f06861b62c881c77630fbcd4d    585.2820    498.3530  1042.520000
# faea4b579b0010b32f001ac4b5b9415a         inf         inf          inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b         inf         inf  1448.520000
# fdfd5975c57d7cd2264ef6aff6cb4815    122.3500    121.7800     0.438178
# ff4b033c2a2da4100f0b1e83c49c5f80         inf   2647.0900          inf
#
#                                   ParaFROST_NoMDM  SLIME_hess_no_rnd  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64          8.14135           86.87150
# 0041051c73dcdd885d412a38e8b09fba        817.84700                inf
# 004b0f451f7d96f6a572e9e76360f51a         65.27380          271.41900
# 0107f34364dfff8ab062193b2c71b4de        129.31000          293.24000
# 01135f7a79d555bd0406f00fac22cbe2              inf                inf
# ...                                           ...                ...
# fab5698f06861b62c881c77630fbcd4d        658.65200         1063.55000
# faea4b579b0010b32f001ac4b5b9415a              inf                inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b        651.72800                inf
# fdfd5975c57d7cd2264ef6aff6cb4815        342.08900            1.37041
# ff4b033c2a2da4100f0b1e83c49c5f80              inf          903.73200
#
#                                   SLIME_hess_rnd  SLIME_no_hess_no_rnd  \
# hash
# 000a41cdca43be89ed62ea3abf2d0b64       105.98600              89.22070
# 0041051c73dcdd885d412a38e8b09fba             inf                   inf
# 004b0f451f7d96f6a572e9e76360f51a       542.56400             267.06500
# 0107f34364dfff8ab062193b2c71b4de       233.12800             203.81800
# 01135f7a79d555bd0406f00fac22cbe2             inf                   inf
# ...                                          ...                   ...
# fab5698f06861b62c881c77630fbcd4d       787.87100             565.02300
# faea4b579b0010b32f001ac4b5b9415a             inf                   inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b             inf                   inf
# fdfd5975c57d7cd2264ef6aff6cb4815         1.37125               1.37725
# ff4b033c2a2da4100f0b1e83c49c5f80      2259.23000            1293.48000
#
#                                   SLIME_no_hess_rnd
# hash
# 000a41cdca43be89ed62ea3abf2d0b64           40.43220
# 0041051c73dcdd885d412a38e8b09fba                inf
# 004b0f451f7d96f6a572e9e76360f51a           73.44250
# 0107f34364dfff8ab062193b2c71b4de          179.98100
# 01135f7a79d555bd0406f00fac22cbe2                inf
# ...                                             ...
# fab5698f06861b62c881c77630fbcd4d          789.02600
# faea4b579b0010b32f001ac4b5b9415a                inf
# fb621b2b4a54ec0f01ac36daaa7f0f5b                inf
# fdfd5975c57d7cd2264ef6aff6cb4815            1.37077
# ff4b033c2a2da4100f0b1e83c49c5f80                inf
#
# [400 rows x 29 columns]

# %%
pd.DataFrame.from_records(list(sorted(zip(
    runtimes_sc2021_df.columns,
    np.mean(runtimes_sc2021_df.replace(np.inf, 10000), axis=0)
), key=lambda x: x[1])), columns=["Algorithm", "PAR-2 score"]).set_index("Algorithm", drop=True)
# Out:
#                        PAR-2 score
# Algorithm
# Kissat_MAB             3194.610178
# Kissat_sc2021_sweep    3365.216217
# kissat_gb              3366.487862
# kissat_crvr_gb         3398.383336
# kissat_cf              3508.211038
# hKis                   3535.051081
# cadical_watch_sat      3613.672898
# CaDiCaL_PriPro         3627.878053
# CaDiCaL_PriPro_no_bin  3628.101647
# ParaFROST_NoMDM        3670.013325
# cadical_hack_gb        3674.180899
# ParaFROST              3677.153000
# hCaD                   3715.889996
# CaDiCaL_sc2021         3737.706581
# Cadical_SCAVEL01       3798.052710
# CaDiCaL_rp             3841.661003
# SLIME_no_hess_no_rnd   3875.900751
# SLIME_hess_no_rnd      3896.568154
# CaDiCaL_Stability_HC   3911.156040
# SLIME_hess_rnd         3978.363186
# Maple_simp21           3996.483145
# optsat_R21             4021.631885
# hCaD_psids             4028.167170
# optsat_m21             4049.496059
# SLIME_no_hess_rnd      4058.156010
# cms_expV_gbL           4063.194430
# kissat_bonus           4095.978913
# hKis_psids             4099.195368
# Cadical_SCAVEL02       4136.509512

# %%
np.count_nonzero(np.isnan(runtimes_sc2021_df))
# Out:
# 0

# %%
with open("./pickled-data/runtimes_sc2020_df.pkl", "wb") as file:
    pickle.dump(runtimes_sc2020_df, file)
with open("./pickled-data/runtimes_sc2021_df.pkl", "wb") as file:
    pickle.dump(runtimes_sc2021_df, file)

# %% [markdown]
# ## Anniversay Data

# %%
import numpy as np
import pandas as pd

from gbd_tool.gbd_api import GBD
    
# Meta-data dataframe
# with GBD(["gbd-data/meta.db"]) as gbd:
#     features = gbd.get_features()
#     features.remove("hash")
#     meta_df = pd.DataFrame.from_records(
#         gbd.query_search("", resolve=features),
#         columns=gbd.get_features())
#     meta_df.set_index("hash", inplace=True)
    
meta_df.shape
# Out:
# (29358, 9)

# %%
anni_df = pd.read_csv("./anni-seq.csv", index_col="hash")
anni_df = anni_df[anni_df.index.isin(meta_df.index)].copy()
anni_df = anni_df.replace(10000.0, np.inf).copy()
anni_df.shape
# Out:
# (5306, 23)

# %%
np.count_nonzero(np.isinf(anni_df))
# Out:
# 32171

# %%
from sklearn.model_selection import train_test_split

# Assign family label other to small families
anni_meta_df = meta_df.loc[anni_df.index, "family"]
all_families = anni_meta_df.unique()
small_families_mask = anni_meta_df.value_counts(sort=False) < 10
small_families = all_families[small_families_mask]
stratifcation_values = np.where(anni_meta_df.isin(small_families), "other", anni_meta_df)

anni_train_df = train_test_split(
    anni_df, test_size=0.1,
    stratify=stratifcation_values,
    shuffle=True, random_state=42,
)[1]

anni_train_df
# Out:
#                                      solver0     solver1     solver2  \
# hash
# 5c409dd2a3ca6066b7de7d72524b1bec  211.589000  209.058000  382.382000
# f33b8989cd1bb1390f0891c9f07a9297    4.208620    4.166500    1.720790
# 3a8409393cc1ebae1444a079d216f221         inf         inf         inf
# 880d9bf224768bf5ff256472682573c8         inf         inf         inf
# 80916cc0ee83c448ca7e1940a0e9e242  583.049000  788.855000  719.921000
# ...                                      ...         ...         ...
# 87daaee8aedd931f03bc3577ce787070  295.656000  202.819000   87.802000
# a405aa15eb2c944245e36038724303b6         inf         inf         inf
# f34ebd8d4ae8ed75e0062971d7809687  494.106000  657.006000  548.303000
# 04935c7718d4ada8516e0d99c46df41b  201.194000  151.927000  140.308000
# 6e8c9d4c7c9f9081dd9029e6436ff349    0.236846    0.235757    0.236469
#
#                                      solver3     solver4    solver5  \
# hash
# 5c409dd2a3ca6066b7de7d72524b1bec  356.126000   45.299800  101.34000
# f33b8989cd1bb1390f0891c9f07a9297    8.123540    0.993691    2.21728
# 3a8409393cc1ebae1444a079d216f221         inf         inf        inf
# 880d9bf224768bf5ff256472682573c8         inf         inf        inf
# 80916cc0ee83c448ca7e1940a0e9e242  476.879000   15.687600   43.35890
# ...                                      ...         ...        ...
# 87daaee8aedd931f03bc3577ce787070  139.947000  198.223000  463.85800
# a405aa15eb2c944245e36038724303b6         inf         inf        inf
# f34ebd8d4ae8ed75e0062971d7809687  107.355000  331.516000   52.57340
# 04935c7718d4ada8516e0d99c46df41b  151.988000   46.577500   28.32080
# 6e8c9d4c7c9f9081dd9029e6436ff349    0.195374    0.236498    0.31516
#
#                                     solver6     solver7     solver8  \
# hash
# 5c409dd2a3ca6066b7de7d72524b1bec   43.27520   43.579700  143.864000
# f33b8989cd1bb1390f0891c9f07a9297    9.45244    4.008910    4.253720
# 3a8409393cc1ebae1444a079d216f221        inf         inf         inf
# 880d9bf224768bf5ff256472682573c8        inf         inf         inf
# 80916cc0ee83c448ca7e1940a0e9e242  343.61000   56.457800  679.248000
# ...                                     ...         ...         ...
# 87daaee8aedd931f03bc3577ce787070  130.66000  163.652000  120.484000
# a405aa15eb2c944245e36038724303b6        inf         inf         inf
# f34ebd8d4ae8ed75e0062971d7809687   22.89310  332.744000  719.995000
# 04935c7718d4ada8516e0d99c46df41b   28.18640   28.138400   60.479600
# 6e8c9d4c7c9f9081dd9029e6436ff349    0.22554    0.225742    0.403914
#
#                                      solver9  ...     solver13    solver14  \
# hash                                          ...
# 5c409dd2a3ca6066b7de7d72524b1bec  569.148000  ...   286.601000         inf
# f33b8989cd1bb1390f0891c9f07a9297    6.959190  ...    11.692300    4.092760
# 3a8409393cc1ebae1444a079d216f221         inf  ...          inf         inf
# 880d9bf224768bf5ff256472682573c8         inf  ...          inf         inf
# 80916cc0ee83c448ca7e1940a0e9e242  112.409000  ...  2173.160000  352.134000
# ...                                      ...  ...          ...         ...
# 87daaee8aedd931f03bc3577ce787070  252.845000  ...   512.281000  133.361000
# a405aa15eb2c944245e36038724303b6         inf  ...          inf         inf
# f34ebd8d4ae8ed75e0062971d7809687   21.548200  ...   566.410000  483.374000
# 04935c7718d4ada8516e0d99c46df41b    4.621400  ...    11.524200  471.822000
# 6e8c9d4c7c9f9081dd9029e6436ff349    0.325107  ...     0.096872    0.178137
#
#                                     solver15    solver16    solver17  \
# hash
# 5c409dd2a3ca6066b7de7d72524b1bec  361.499000    8.550080   51.275300
# f33b8989cd1bb1390f0891c9f07a9297    1.165640    8.988620    5.967610
# 3a8409393cc1ebae1444a079d216f221         inf         inf         inf
# 880d9bf224768bf5ff256472682573c8         inf         inf         inf
# 80916cc0ee83c448ca7e1940a0e9e242  107.157000  500.656000  179.494000
# ...                                      ...         ...         ...
# 87daaee8aedd931f03bc3577ce787070  489.407000  383.161000  143.748000
# a405aa15eb2c944245e36038724303b6         inf         inf         inf
# f34ebd8d4ae8ed75e0062971d7809687  111.465000    5.265540  216.766000
# 04935c7718d4ada8516e0d99c46df41b   57.169800   12.533700  331.583000
# 6e8c9d4c7c9f9081dd9029e6436ff349    0.255747    0.284776    0.359048
#
#                                    solver18   solver19    solver20  \
# hash
# 5c409dd2a3ca6066b7de7d72524b1bec  113.84600   10.10910  101.537000
# f33b8989cd1bb1390f0891c9f07a9297    4.92229    7.92587    0.499766
# 3a8409393cc1ebae1444a079d216f221        inf        inf         inf
# 880d9bf224768bf5ff256472682573c8        inf        inf         inf
# 80916cc0ee83c448ca7e1940a0e9e242  565.63400  700.17800  362.371000
# ...                                     ...        ...         ...
# 87daaee8aedd931f03bc3577ce787070  238.10700  255.88000  664.937000
# a405aa15eb2c944245e36038724303b6        inf        inf         inf
# f34ebd8d4ae8ed75e0062971d7809687  110.07000   27.76900   31.244100
# 04935c7718d4ada8516e0d99c46df41b  357.03900  129.48500   96.857400
# 6e8c9d4c7c9f9081dd9029e6436ff349    0.33678    0.24484    0.241422
#
#                                     solver21     solver22
# hash
# 5c409dd2a3ca6066b7de7d72524b1bec  228.439000  1842.650000
# f33b8989cd1bb1390f0891c9f07a9297    3.307000     8.103540
# 3a8409393cc1ebae1444a079d216f221         inf          inf
# 880d9bf224768bf5ff256472682573c8         inf          inf
# 80916cc0ee83c448ca7e1940a0e9e242  425.068000   696.669000
# ...                                      ...          ...
# 87daaee8aedd931f03bc3577ce787070   64.207400   313.376000
# a405aa15eb2c944245e36038724303b6         inf  4664.340000
# f34ebd8d4ae8ed75e0062971d7809687   33.287700    92.242500
# 04935c7718d4ada8516e0d99c46df41b  291.244000   115.283000
# 6e8c9d4c7c9f9081dd9029e6436ff349    0.190638     0.192653
#
# [531 rows x 23 columns]

# %%
meta_df.loc[anni_df.index, "family"].value_counts()
# Out:
# unknown                         659
# hardware-verification           344
# cryptography                    308
# planning                        252
# bitvector                       214
#                                ...
# maximum-constraint-partition      2
# 01-integer-programming            2
# circuit-minimization              2
# ssp-0                             2
# glassy-gen                        1
# Name: family, Length: 130, dtype: int64

# %%
meta_df.loc[anni_train_df.index, "family"].value_counts()
# Out:
# unknown                     66
# hardware-verification       35
# cryptography                31
# planning                    25
# bitvector                   21
#                             ..
# ordering-principle           1
# maxsat-optimum               1
# sliding-puzzle               1
# automata-synchronization     1
# mycielski-graph              1
# Name: family, Length: 109, dtype: int64

# %%
import pickle

with open("./pickled-data/anni_df.pkl", "wb") as file:
    pickle.dump(anni_df.copy(), file)
with open("./pickled-data/anni_train_df.pkl", "wb") as file:
    pickle.dump(anni_train_df.copy(), file)

# %%
np.count_nonzero(np.isinf(anni_train_df))
# Out:
# 3291

# %%
np.count_nonzero(anni_df.index.isin(base_features_df.index)) / anni_df.shape[0]
# Out:
# 1.0

# %%
np.count_nonzero(anni_df.index.isin(main_sat_2020_hashes))
# Out:
# 354

# %%
np.count_nonzero(anni_df.index.isin(main_sat_2021_hashes))
# Out:
# 362

# %%
r = {}
for v in main_sat_2021_hashes.values:
    c = np.count_nonzero(meta_df["isohash"] == (meta_df.loc[meta_df["hash"] == v, "isohash"].iloc[0]))
    if c in r:
        r[c] += 1
    else:
        r[c] = 1
pd.DataFrame.from_records(list(sorted(r.items())), columns=["Num. Occ. Iso-Hash", "Num. Instance"])
# Out:
#    Num. Occ. Iso-Hash  Num. Instance
# 0                   1            381
# 1                   2             16
# 2                  15              3

# %%
pd.DataFrame.from_records(list(sorted(zip(
    anni_df.columns,
    np.mean(anni_df.replace(np.inf, 10000), axis=0)
), key=lambda x: x[1])), columns=["Algorithm", "PAR-2 score"]).set_index("Algorithm", drop=True)
# Out:
#            PAR-2 score
# Algorithm
# solver5    2805.617124
# solver18   2810.395403
# solver12   2832.694092
# solver7    2833.073926
# solver20   2834.378091
# solver11   2842.625442
# solver6    2844.245802
# solver4    2855.160861
# solver19   2866.818358
# solver17   2897.027855
# solver15   2950.843099
# solver8    2964.831562
# solver9    2973.907731
# solver16   3011.579217
# solver3    3015.101927
# solver2    3034.035587
# solver22   3039.395837
# solver10   3047.205521
# solver21   3077.921003
# solver0    3093.025069
# solver1    3098.479042
# solver13   3270.944152
# solver14   3432.889514

# %%
pd.DataFrame.from_records(list(sorted(zip(
    anni_train_df.columns,
    np.mean(anni_train_df.replace(np.inf, 10000), axis=0)
), key=lambda x: x[1])), columns=["Algorithm", "PAR-2 score"]).set_index("Algorithm", drop=True)
# Out:
#            PAR-2 score
# Algorithm
# solver5    2805.801785
# solver4    2833.091481
# solver6    2845.194253
# solver12   2852.985377
# solver7    2857.423019
# solver18   2865.824259
# solver20   2871.853832
# solver11   2891.439584
# solver17   2894.019080
# solver19   2948.166571
# solver9    2951.089600
# solver15   2964.896296
# solver16   2996.964381
# solver8    3025.710083
# solver10   3083.245276
# solver22   3097.997206
# solver3    3107.126621
# solver21   3110.966494
# solver2    3146.187372
# solver0    3170.563073
# solver13   3253.737877
# solver1    3283.143189
# solver14   3609.420783

# %% [markdown]
# ## Final Anniversary Data

# %%
import numpy as np
import pandas as pd

from gbd_tool.gbd_api import GBD
    
# Meta-data dataframe
with GBD(["gbd-data/meta.db"]) as gbd:
    features = gbd.get_features()
    features.remove("hash")
    meta_df = pd.DataFrame.from_records(
        gbd.query_search("", resolve=features),
        columns=gbd.get_features())
    meta_df.set_index("hash", inplace=True)
    
meta_df.shape
# Out:
# (29922, 9)

# %%
anni_df = pd.read_csv("./anni-seq-final.csv", index_col="hash", sep=" ")
anni_df.drop(["benchmark", "verified-result", "claimed-result"], axis=1, inplace=True)
anni_df = anni_df[anni_df.index.isin(base_features_df.index)].copy()
anni_df = anni_df.replace(10000.0, np.inf).copy()
anni_df.shape
# Out:
# (5301, 28)

# %%
pd.DataFrame.from_records(list(sorted(zip(
    anni_df.columns,
    np.mean(anni_df.replace(np.inf, 10000), axis=0)
), key=lambda x: x[1])), columns=["Algorithm", "PAR-2 score"]).set_index("Algorithm", drop=True)
# Out:
#                          PAR-2 score
# Algorithm
# Kissat_MAB_ESA           2808.131702
# kissat-sc2022-bulky      2812.931160
# ekissat-mab-gb-db        2835.247538
# Kissat_MAB_UCB           2835.594988
# kissat_inc               2836.915263
# ekissat-mab-db-v1        2845.189361
# Kissat_MAB_MOSS          2846.732671
# Kissat_MAB-HyWalk        2857.666290
# kissat-sc2022-light      2869.454962
# kissat-els-v2            2899.695461
# hKis-unsat               2953.593305
# Kissat_adaptive_restart  2967.533663
# SeqFROST-NoExtend        2976.561176
# kissat-els-v1            3014.403540
# Cadical_ESA              3017.733615
# CadicalReorder           3036.825750
# cadical_rel_Scavel       3049.901243
# kissat_relaxed           3080.658743
# CaDiCaL_DVDL_V1          3095.727060
# CaDiCaL_DVDL_V2          3101.124640
# glucose-reboot           3273.946417
# LStech-Maple-HyWalk      3290.896185
# LSTech_Maple             3292.681722
# SLIME-SC-2022-beta       3400.721026
# SLIME-SC-2022            3412.113031
# hCaD_V1-psids            3436.072494
# MapleLCMDistChrBt-DL-v3  3506.318901
# IsaSAT                   4741.502711

# %%
np.count_nonzero(anni_df.index.isin(meta_df.index)), anni_df.shape[0]
# Out:
# (5301, 5301)

# %%
np.count_nonzero(anni_df.index.isin(base_features_df.index)), anni_df.shape[0]
# Out:
# (5301, 5301)

# %%
with open("./pickled-data/anni_final_df.pkl", "wb") as file:
    pickle.dump(anni_df.copy(), file)

# %%
import numpy as np
import pandas as pd
import pickle

anni_full_df = pd.read_csv("./anni-seq-final.csv", index_col="hash", sep=" ")
anni_full_df.drop(["benchmark", "verified-result", "claimed-result"], axis=1, inplace=True)
anni_full_df = anni_full_df.replace(10000.0, np.inf).copy()

with open("./pickled-data/anni_full_df.pkl", "wb") as file:
    pickle.dump(anni_full_df.copy(), file)

anni_full_df.shape
# Out:
# (5355, 28)
